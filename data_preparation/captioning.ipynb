# %% [markdown]
# ### This notebook uses only the **rendered images** for captioning

# %%
# Import necessary libraries
import os
import jsonlines
import json
import openai
import csv
import base64
import tiktoken
import time
from time import time
from openai import OpenAI

# Set OpenAI API key
# Load API key from environment variable for security
# Set the OPENAI_API_KEY environment variable before running this notebook:
# export OPENAI_API_KEY='your-api-key-here'
openai.api_key = os.getenv("OPENAI_API_KEY")

if not openai.api_key:
    raise ValueError("OPENAI_API_KEY environment variable not set. Please set it before running this notebook.")
# Out:
# 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

# %%
# Define directories and file paths
step_dir = "/home/group/cad_codebased/data/abccad/step_under500/abc_0001_step_v00_under500"  
# step_dir = "/home/group/cad_codebased/data/abccad/test_purpose_only/step"   #"/home/group/cad_codebased/data/abccad_test/0001_step_500"
image_dir = "/home/group/cad_codebased/data/abccad/step_under500_image/abc_0001_step_v00_under500_image"    #"/home/group/cad_codebased/data/abccad_test/0001_step_500_images"
# image_dir = "/home/group/cad_codebased/data/abccad/test_purpose_only/image"  
output_csv = "cad_captions.csv"

# %%
# Encode image as base64
def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")

# %%
# Test image encoding
image_path = "/home/group/cad_codebased/data/abccad/step_under500_image/abc_0004_step_v00_under500_image/00040014_dfb67f543711434fb5751d3f_step_003.jpeg"
base64_image = encode_image(image_path)
print(base64_image)
# Out:
# ...

# %%
# Extract DATA section from STEP file
def extract_data_section(step_path):
    step_content = []
    data_section_found = False
    with open(step_path, "r") as f:
        for line in f:
            if "DATA;" in line:
                data_section_found = True
            if data_section_found:
                step_content.append(line)
    return "".join(step_content)

# %%
# Calculate token count using tiktoken
def calculate_tokens(messages, encoder):
    total_tokens = 0
    for message in messages:
        if isinstance(message["content"], list):
            for content_item in message["content"]:
                if "text" in content_item:
                    total_tokens += len(encoder.encode(content_item["text"]))
        else:
            total_tokens += len(encoder.encode(message["content"]))
    return total_tokens

# %%
def get_caption(text_message, image_message):
    client = OpenAI()
    response = client.chat.completions.create(
        model="gpt-4o",
        temperature=0.2,
        max_tokens=300,
        messages=[
            {
                "role": "system",
                "content": "You are a helpful assistant specialized in CAD analysis."
            },
            {
                "role": "user", "content": [text_message, image_message]
            }
        ]
    )

    return response.choices[0].message.content

# %% [markdown]
# ### DO NOT USE THIS PROMPT

# %%
# Process directory of STEP files and save results
def process_directory(step_dir, image_dir, output_csv):
    encoder = tiktoken.get_encoding("o200k_base")    # gpt-4o uses o200k_base

    existing_model_ids = set()
    if os.path.exists(output_csv):
        with open(output_csv, mode="r", newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                existing_model_ids.add(row["model_id"])

    # Count total number of STEP files to process
    total_files = 0
    for subfolder in os.listdir(step_dir):
        subfolder_path = os.path.join(step_dir, subfolder)
        if os.path.isdir(subfolder_path):
            for step_file in os.listdir(subfolder_path):
                if step_file.endswith(".step"):
                    model_id = step_file.split('_')[0]
                    if model_id not in existing_model_ids:
                        total_files += 1

    processed_count = 0
    
    with open(output_csv, mode="a", newline="") as csvfile:
        fieldnames = ["model_id", "isDescribable", "description", "token_count"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        # Write the header only if the file is newly created
        if not existing_model_ids:
            writer.writeheader()

        for subfolder in os.listdir(step_dir):
            subfolder_path = os.path.join(step_dir, subfolder)
            if os.path.isdir(subfolder_path):
                for step_file in os.listdir(subfolder_path):
                    if step_file.endswith(".step"):
                        model_id = step_file.split('_')[0]

                        # Skip processing if the model_id already exists in the output CSV
                        if model_id in existing_model_ids:
                            print(f"Skipping {step_file}, already processed.")
                            continue
                        
                        step_path = os.path.join(subfolder_path, step_file)
                        image_path = os.path.join(image_dir, f"{step_file.split('.')[0]}.jpeg")

                        if not os.path.exists(image_path):
                            print(f"Warning: Missing image for {step_file}")
                            continue

                        step_content = extract_data_section(step_path)
                        base64_image = encode_image(image_path)

                        text_message = {
                            "type": "text",
                            "text": f"""

                            You are provided with a multi-view image of a single CAD model. Each image shows the same object from a different perspective. 

                            Please follow these precise instructions:

                            1. **Determine describability**: Assess whether this CAD model (as a whole) can be described using a short natural language caption. Do not describe individual views or interpret them as separate objects. Even if the model consists of multiple connected or adjacent parts, treat it as one entity.

                            2. **Important note on views**:
                            - The **top row** contains standard orthographic projections (e.g., front, top, side views). These provide reliable geometric clues such as length, thickness, angles, and symmetry. Use them as the primary reference for structure.
                            - The lower rows show perspective views from various angles to supplement spatial understanding.
                            - Do **not** mistakenly infer that multiple views indicate multiple separate objects. They are different renderings of the **same** CAD model.
                            - Carefully observe small but important features such as through holes, indentations, internal cavities, or partial hollowness. These details matter in the description.

                            3. **Perspective reasoning**: 
                            - Infer depth, flatness, holes, or slopes using the combination of orthographic and perspective views. Be cautious not to misinterpret shading or foreshortening.
                            - Do not invent geometric features based on misleading perspective. For example, do not describe a cube as having a "triangular" or "diamond-shaped" face just because of viewing angle.

                            4. **Output requirements**:
                            - If the object has a clear, describable geometric or functional shape (e.g., “a cylindrical rod with a flange”,"a water cup"), set `isDescribable: true` and provide a concise description (1–2 lines max).
                            - If the object appears abstract, highly irregular, or does not admit any concise description, set `isDescribable: false`.

                            5.Common mistakes to avoid:
                            - Misinterpreting perspective views as separate parts or separate objects.
                            - Misclassifying flat rectangular plates or cubes as having diamond, triangular, pyramid, or prism-like shapes.
                            - Ignoring holes or cutouts in discs, rods, or tapered parts.
                            - Incorrectly assuming a part is completely solid or completely hollow without checking views.

                            6. **Return the result strictly as a JSON object**, with no commentary or explanation. For example:
                            ```json
                            {{
                            "isDescribable": true,
                            "description": "A cylindrical rod with a conical tip and a flanged base."
                            }}
                            """
                        }

                        image_message = {
                            "type": "image_url",
                            "image_url": {
                                "url": f"data:image/jpeg;base64,{base64_image}"
                            }
                        }

                        messages = [
                            {
                                "role": "system",
                                "content": "You are a helpful assistant specialized in CAD analysis."
                            },
                            {
                                "role": "user", "content": [text_message, image_message]
                            }
                        ]

                        token_count = calculate_tokens(messages, encoder)
                        start_time = time()
                        caption = get_caption(text_message, image_message)
                        end_time = time()

                        print(f"Processed {step_file} in {end_time - start_time:.2f} seconds")
                        #print(caption)

                        # Parse response
                        try:
                            # Remove extraneous characters before parsing
                            caption = caption.strip()
                            if caption.startswith("```json"):
                                caption = caption.lstrip("```json").rstrip("```")
                            caption_data = json.loads(caption)
                            is_describable = caption_data.get("isDescribable", "N/A")
                            description = caption_data.get("description", "N/A")
                        except json.JSONDecodeError as e:
                            print(f"JSON parsing error for {step_file}: {e}\nRaw response:\n{caption}")
                            is_describable = "Error"
                            description = "Error"


                        writer.writerow({
                            "model_id": model_id,
                            "isDescribable": is_describable,
                            "description": description,
                            "token_count": token_count
                        })

                        processed_count += 1

                        # Print progress every 100 processed files
                        if processed_count % 50 == 0 or processed_count == total_files:
                            print(f"Processed: {processed_count}/{total_files}")

# %% [markdown]
# ### DO NOT USE THIS PROMPT

# %%
def process_directory_from_images(image_dir, output_csv):
    encoder = tiktoken.get_encoding("o200k_base")  # gpt-4o uses o200k_base

    existing_model_ids = set()
    if os.path.exists(output_csv):
        with open(output_csv, mode="r", newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                existing_model_ids.add(row["model_id"])

    image_files = []
    for f in os.listdir(image_dir):
        if f.endswith(".jpeg") and f.split("_")[0] not in existing_model_ids:
            image_files.append(f)
        else:
            print(f"Skipping {f}, already processed.")
    total_files = len(image_files)
    processed_count = 0

    with open(output_csv, mode="a", newline="") as csvfile:
        fieldnames = ["model_id", "isDescribable", "description", "token_count"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        if not existing_model_ids:
            writer.writeheader()

        for image_file in image_files:
            model_id = image_file.split("_")[0]
            image_path = os.path.join(image_dir, image_file)
            # if model_id in existing_model_ids:
            #                 print(f"Skipping {step_file}, already processed.")
            #                 continue

            if not os.path.exists(image_path):
                print(f"Warning: Missing image {image_file}")
                continue

            base64_image = encode_image(image_path)

            text_message = {
                "type": "text",
                "text": f"""
                You are provided with a multi-view image of a single CAD model. Each image shows the same object from a different perspective. 

                Please follow these precise instructions:

                1. **Determine describability**: Assess whether this CAD model (as a whole) can be described using a short natural language caption. Do not describe individual views or interpret them as separate objects. Even if the model consists of multiple connected or adjacent parts, treat it as one entity.
                2. **Important note on views**:
                - The **top row** contains standard orthographic projections (e.g., front, top, side views). These provide reliable geometric clues such as length, thickness, angles, and symmetry. Use them as the primary reference for structure.
                - The lower rows show perspective views from various angles to supplement spatial understanding.
                - Do **not** mistakenly infer that multiple views indicate multiple separate objects. They are different renderings of the **same** CAD model.
                - Carefully observe small but important features such as through holes, indentations, internal cavities, or partial hollowness. These details matter in the description.

                3. **Perspective reasoning**: 
                - Infer depth, flatness, holes, or slopes using the combination of orthographic and perspective views. Be cautious not to misinterpret shading or foreshortening.
                - Do not invent geometric features based on misleading perspective. For example, do not describe a cube as having a "triangular" or "diamond-shaped" face just because of viewing angle.

                4. **Output requirements**:
                - If the object has a clear, describable geometric or functional shape (e.g., “a cylindrical rod with a flange”,"a water cup"), set `isDescribable: true` and provide a concise description (1–2 lines max).
                - If the object appears abstract, highly irregular, or does not admit any concise description, set `isDescribable: false`.

                5. **Real-world class guessing (encouraged)**:
                - When the object **clearly resembles a real-world item** — such as a cup, plate, wheel, bolt, gear, bracket, or hinge — you are encouraged to **label it accordingly** in the description, as long as the geometry supports that interpretation.
                - Be conservative and only assign class-like names (e.g., “a hinge”, “a pipe connector”) when the overall shape and structure strongly suggest the function or category.
                - If unsure, default to a purely geometric description.

                6. Common mistakes to avoid:
                - Misinterpreting perspective views as separate parts or separate objects.
                - Misclassifying flat rectangular plates, rectangular blocks, or cubes as having diamond, triangular, or pyramid-like shapes.
                - Ignoring holes or cutouts in discs, rods, or tapered parts.
                - Incorrectly assuming a part is completely solid or completely hollow without checking views.
                - Failing to distinguish between the object (colored in brown) and the background (colored in grey), treating a thin ring as a disc or plate.
                - Mistaking uniformly thick plates, rods, or disks for unevenly thick ones.
                
                7. **Return the result strictly as a JSON object**, with no commentary or explanation. For example:
                ```json
                {{
                "isDescribable": true,
                "description": "A cylindrical rod with a conical tip and a flanged base."
                }}
                """
            }

            image_message = {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{base64_image}"
                }
            }

            messages = [
                {
                    "role": "system",
                    "content": "You are a helpful assistant specialized in CAD analysis."
                },
                {
                    "role": "user",
                    "content": [text_message, image_message]
                }
            ]

            token_count = calculate_tokens(messages, encoder)
            start_time = time()
            caption = get_caption(text_message, image_message)
            end_time = time()

            print(f"Processed {image_file} in {end_time - start_time:.2f} seconds")

            try:
                caption = caption.strip()
                if caption.startswith("```json"):
                    caption = caption.lstrip("```json").rstrip("```")
                caption_data = json.loads(caption)
                is_describable = caption_data.get("isDescribable", "N/A")
                description = caption_data.get("description", "N/A")
            except json.JSONDecodeError as e:
                print(f"JSON parsing error for {image_file}: {e}\nRaw response:\n{caption}")
                is_describable = "Error"
                description = "Error"

            writer.writerow({
                "model_id": model_id,
                "isDescribable": is_describable,
                "description": description,
                "token_count": token_count
            })

            processed_count += 1
            if processed_count % 50 == 0 or processed_count == total_files:
                print(f"Processed: {processed_count}/{total_files}")

# %% [markdown]
# ### USE THIS PROMPT

# %%
def process_directory_from_images(image_dir, output_csv):
    encoder = tiktoken.get_encoding("o200k_base")  # gpt-4o uses o200k_base

    existing_model_ids = set()
    if os.path.exists(output_csv):
        with open(output_csv, mode="r", newline="") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                existing_model_ids.add(row["model_id"])

    image_files = []
    for f in os.listdir(image_dir):
        if f.endswith(".jpeg") and f.split("_")[0] not in existing_model_ids:
            image_files.append(f)
        else:
            print(f"Skipping {f}, already processed.")
    total_files = len(image_files)
    processed_count = 0

    with open(output_csv, mode="a", newline="") as csvfile:
        fieldnames = ["model_id", "isDescribable", "description", "token_count"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        if not existing_model_ids:
            writer.writeheader()

        for image_file in image_files:
            model_id = image_file.split("_")[0]
            image_path = os.path.join(image_dir, image_file)
            # if model_id in existing_model_ids:
            #                 print(f"Skipping {step_file}, already processed.")
            #                 continue

            if not os.path.exists(image_path):
                print(f"Warning: Missing image {image_file}")
                continue

            base64_image = encode_image(image_path)

            text_message = {
                "type": "text",
                "text": f"""
                You are provided with a multi-view image of a single CAD model. Each image shows the same object from a different perspective. 

                Please follow these precise instructions:

                1. Determine describability: Assess whether this CAD model (as a whole) can be described using a short natural language caption. Do not describe individual views or interpret them as separate objects. Even if the model consists of multiple connected or adjacent parts, treat it as one entity.
                2. Important note on views:
                - There are 9 views in total, arranged in 3 rows and 3 columns.
                - The top row contains standard orthographic projections (e.g., front, top, side views). These provide reliable geometric clues such as length, thickness, angles, and symmetry. Use them as the primary reference for structure.
                - The lower rows show perspective views from various angles to supplement spatial understanding.
                - Do not mistakenly infer that multiple views indicate multiple separate objects. They are different renderings of the same CAD model.
                - Carefully observe small but important features such as through holes, indentations, internal cavities, or partial hollowness. These details matter in the description.

                3. Perspective reasoning: 
                - Infer depth, flatness, holes, or slopes using the combination of orthographic and perspective views. Be cautious not to misinterpret shading or foreshortening.
                - Do not invent geometric features based on misleading perspective. For example, do not describe a cube as having a "triangular" or "diamond-shaped" face just because of viewing angle.
                - If it can be judged as a cube from the top row images, simply state it "A cube".
                - If it can be judged as a rectangular block from the top row images, simply state it "A rectangular block".
                - Be coutious about using the word "tapered", double check the top row images to see if it is really a tapered part or not.

                4. Output requirements:
                - If the object has a clear, describable geometric or functional shape (e.g., “a cylindrical rod with a flange”,"a water cup"), set `isDescribable: true` and provide a concise description (1-2 lines max).
                - If the object appears abstract, highly irregular, or does not admit any concise description, set `isDescribable: false`.

                5. Real-world class guessing (encouraged):
                - When the object clearly resembles a real-world item — such as a cup, plate, wheel, bolt, gear, bracket, or hinge — you are encouraged to label it accordingly in the description, as long as the geometry supports that interpretation.
                - Assign class-like names (e.g., “a hinge”, “a pipe connector”) when the overall shape and structure strongly suggest the function or category.
                - If unsure, default to a purely geometric description.

                6. Common mistakes to avoid:
                - Misinterpreting perspective views as separate parts or separate objects.
                - Misclassifying flat rectangular plates, rectangular blocks, or cubes as having diamond, triangular, or pyramid-like shapes.
                - Ignoring holes or cutouts in discs, rods, or tapered parts.
                - Incorrectly assuming a part is completely solid or completely hollow without checking views.
                - Failing to distinguish between the object (colored in brown) and the background (colored in grey), treating a thin ring as a disc or plate.
                - Mistaking uniformly thick plates, rods, or disks for unevenly thick ones.
                - Do not describe a cube as "A cube with a triangular prism on top" or "A cube with a pyramid on top of one face."
                - Do not describe a rectangular block as "A rectangular block with a triangular prism on top" or "A rectangular block with a pyramid on top of one face."
                
                7. **Return the result strictly as a JSON object**, with no commentary or explanation. For example:
                ```json
                {{
                "isDescribable": true,
                "description": "A cylindrical rod with a conical tip and a flanged base."
                }}
                """
            }

            image_message = {
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/jpeg;base64,{base64_image}"
                }
            }

            messages = [
                {
                    "role": "system",
                    "content": "You are a helpful assistant specialized in CAD analysis."
                },
                {
                    "role": "user",
                    "content": [text_message, image_message]
                }
            ]

            token_count = calculate_tokens(messages, encoder)
            start_time = time()
            caption = get_caption(text_message, image_message)
            end_time = time()

            print(f"Processed {image_file} in {end_time - start_time:.2f} seconds")

            try:
                caption = caption.strip()
                if caption.startswith("```json"):
                    caption = caption.lstrip("```json").rstrip("```")
                caption_data = json.loads(caption)
                is_describable = caption_data.get("isDescribable", "N/A")
                description = caption_data.get("description", "N/A")
            except json.JSONDecodeError as e:
                print(f"JSON parsing error for {image_file}: {e}\nRaw response:\n{caption}")
                is_describable = "Error"
                description = "Error"

            writer.writerow({
                "model_id": model_id,
                "isDescribable": is_describable,
                "description": description,
                "token_count": token_count
            })

            processed_count += 1
            if processed_count % 50 == 0 or processed_count == total_files:
                print(f"Processed: {processed_count}/{total_files}")

# %%
# process_directory(step_dir, image_dir, output_csv)
process_directory_from_images(image_dir, output_csv)
print(f"Results saved to {output_csv}")
# Out:
# Processed 00018258_b05e9c3f7ba3435383c5dc13_step_000.jpeg in 3.05 seconds
# Processed 00014086_3a10a9f5df754f9ba26fd937_step_000.jpeg in 6.80 seconds
# Processed 00019488_c3009b533e43403489163a78_step_006.jpeg in 1.61 seconds
# Processed 00012291_f0fd9593510d4663a67b9a45_step_006.jpeg in 4.84 seconds
# Processed 00019664_ede04fe6b17549b2bc7f5c4b_step_003.jpeg in 2.33 seconds
# Processed 00013445_64f1e17b08b142d8886288bd_step_002.jpeg in 1.78 seconds
# Processed 00011960_6a6aa1d1dfc84bc3bbc0fa85_step_003.jpeg in 1.28 seconds
# Processed 00018298_79e7f2a8e99b46d282e7d1bd_step_000.jpeg in 1.42 seconds
# Processed 00018726_16fffb32776e4fc899153830_step_000.jpeg in 2.46 seconds
# Processed 00012086_bd0ba1071db44a4cb05e612c_step_021.jpeg in 1.93 seconds
# Processed 00015602_cf31e45c5b0141be9fdb2d8f_step_000.jpeg in 2.31 seconds
# Processed 00011634_8f0deb494b1845cb8eaf4caa_step_003.jpeg in 2.15 seconds
# Processed 00016061_f45f2f2c8dee46c4959c253d_step_006.jpeg in 3.17 seconds
# Processed 00019525_9655da2d553e4710baa505c5_step_002.jpeg in 2.52 seconds
# Processed 00018561_ebede39351224e2597bedd6b_step_000.jpeg in 4.57 seconds
# Processed 00013708_58ac30b6c5ea42f1a00650e6_step_004.jpeg in 2.57 seconds
# Processed 00019797_4bbd66004654476bbcdcaf28_step_000.jpeg in 1.87 seconds
# Processed 00016226_109c897d2b8d49d5a7af94d5_step_001.jpeg in 2.15 seconds
# Processed 00017591_410be2bba5a44473ab723de3_step_036.jpeg in 1.41 seconds
# Processed 00018122_bc8ab2012b6b458c9e2fedf2_step_000.jpeg in 1.84 seconds
# Processed 00010925_5603489948bf4607b991fe99_step_006.jpeg in 2.17 seconds
# Processed 00015760_bca56983eee140db9aa4c9a1_step_101.jpeg in 1.52 seconds
# Processed 00019487_c3009b533e43403489163a78_step_005.jpeg in 1.98 seconds
# Processed 00017135_905452b1fb5b4ca18a1d8a4a_step_002.jpeg in 1.84 seconds
# Processed 00015867_c99e23b9d32845b2b29aaf99_step_000.jpeg in 1.61 seconds
# Processed 00010565_4fb6d6e0256b462d8525f7e6_step_000.jpeg in 1.43 seconds
# Processed 00010531_a8adf76bfb3d4789996949d7_step_007.jpeg in 2.35 seconds
# Processed 00013526_eeab613b0f97413f8492a712_step_027.jpeg in 2.85 seconds
# Processed 00019679_13a5d491d3954212ab167fa5_step_000.jpeg in 2.18 seconds
# Processed 00019486_c3009b533e43403489163a78_step_004.jpeg in 3.39 seconds
# Processed 00014113_546daa68d6f240ba841f8fb2_step_000.jpeg in 2.66 seconds
# Processed 00012869_97d657f2bd0543ccbaad325c_step_019.jpeg in 3.24 seconds
# Processed 00018315_84696173c1a248c4bbe5fc35_step_000.jpeg in 1.45 seconds
# Processed 00015618_61d3d42863804aada8056cf5_step_000.jpeg in 2.20 seconds
# Processed 00016808_d84732cbcd274c709c628f32_step_018.jpeg in 1.67 seconds
# Processed 00011726_1ca1ad2a09504ff1bf83cf74_step_059.jpeg in 1.74 seconds
# Processed 00013889_ec3fde09dd304704b0da3898_step_000.jpeg in 1.44 seconds
# Processed 00015417_0bf937b21a0d4774a719e6be_step_000.jpeg in 1.69 seconds
# Processed 00013232_7da09c1e733c4f69b6ff7346_step_003.jpeg in 6.99 seconds
# Processed 00015757_bca56983eee140db9aa4c9a1_step_098.jpeg in 1.37 seconds
# Processed 00013305_68eb44ebd3f74c1399af56d8_step_003.jpeg in 2.17 seconds
# Processed 00016893_e6c0b0aceeac43d39fe00ed6_step_000.jpeg in 1.50 seconds
# Processed 00016797_d84732cbcd274c709c628f32_step_007.jpeg in 2.96 seconds
# Processed 00017327_f72a043c29a74086996085d3_step_000.jpeg in 1.35 seconds
# Processed 00019190_6c637809a60b4332968aa555_step_000.jpeg in 2.07 seconds
# Processed 00011471_9c5f2a4031124bd982c92ce1_step_000.jpeg in 1.64 seconds
# Processed 00019733_c88e229f9f524e81a9e9d8eb_step_000.jpeg in 1.74 seconds
# Processed 00013007_e7daff2a983941e1aaf7dbd7_step_000.jpeg in 1.57 seconds
# Processed 00014059_93419e6566054c8087881c28_step_003.jpeg in 1.74 seconds
# Processed 00019270_24850bfcb0244cdc90272395_step_000.jpeg in 1.92 seconds
# Processed: 50/2261
# Processed 00011163_db6e2de6f4ae4ec493ebe2aa_step_039.jpeg in 2.43 seconds
# Processed 00014192_8f8cd005cda04a55a165c6d4_step_005.jpeg in 2.13 seconds
# Processed 00012713_79aced0971064c26af542963_step_002.jpeg in 1.19 seconds
# Processed 00017593_410be2bba5a44473ab723de3_step_038.jpeg in 1.78 seconds
# Processed 00010407_3f8b98f0e6b84352819ef9b2_step_010.jpeg in 1.93 seconds
# Processed 00019354_39f94e23e474445ab3eba17c_step_004.jpeg in 1.66 seconds
# Processed 00019748_425b68c945024981a27de1ac_step_000.jpeg in 1.30 seconds
# Processed 00018727_39a4c292a22a4cd78b4c0ee5_step_000.jpeg in 4.52 seconds
# Processed 00018169_8d3d29c89e4c4fd49c2424e5_step_000.jpeg in 1.48 seconds
# Processed 00018610_423ab08382b847da96d9ff89_step_035.jpeg in 4.69 seconds
# Processed 00010415_931da2d93b834469a68d5716_step_004.jpeg in 1.68 seconds
# Processed 00017515_462233e03ca64b68bf0ccd1b_step_001.jpeg in 2.32 seconds
# Processed 00012874_97d657f2bd0543ccbaad325c_step_024.jpeg in 1.60 seconds
# Processed 00019744_5fa536fa0ded4a7bb59f68f8_step_002.jpeg in 1.70 seconds
# Processed 00017811_8fe683f249f044da96cc937a_step_000.jpeg in 2.16 seconds
# Processed 00013207_81a9bf47fde14020863c81e6_step_007.jpeg in 1.41 seconds
# Processed 00015279_dee87786a9594ed5812024cd_step_002.jpeg in 1.64 seconds
# Processed 00019021_52a34dc6c76842228bccadaf_step_004.jpeg in 1.84 seconds
# Processed 00010210_4769314c71814669ba5d3512_step_005.jpeg in 3.91 seconds
# Processed 00011695_1ca1ad2a09504ff1bf83cf74_step_028.jpeg in 3.80 seconds
# Processed 00015456_f8e87729e5cc4d4d81cbeb70_step_001.jpeg in 2.87 seconds
# Processed 00018967_b302da1a26764dd0afcd55ff_step_095.jpeg in 1.68 seconds
# Processed 00010628_db6f589275674b27bafe9997_step_004.jpeg in 1.14 seconds
# Processed 00012991_39a2d8de95d74208b5d639e6_step_000.jpeg in 4.27 seconds
# Processed 00011599_6aabde26d62f459694e124e2_step_000.jpeg in 2.37 seconds
# Processed 00010629_db6f589275674b27bafe9997_step_005.jpeg in 1.75 seconds
# Processed 00017239_6999428e74144d7aa85857e8_step_000.jpeg in 2.00 seconds
# Processed 00013208_81a9bf47fde14020863c81e6_step_008.jpeg in 1.48 seconds
# Processed 00014234_7d0446bccbf94d4aa48f5c28_step_002.jpeg in 1.64 seconds
# Processed 00011967_aa809d0eb10e4aa481ee49cb_step_000.jpeg in 1.55 seconds
# Processed 00019991_7259f13b84f34cce843db1f8_step_034.jpeg in 2.26 seconds
# Processed 00013105_8a05ec40b85e4b039898097c_step_006.jpeg in 1.87 seconds
# Processed 00012462_cee94f8e0b6c4c18bdf1cecf_step_005.jpeg in 1.83 seconds
# Processed 00015374_320c0398d3814426badac60e_step_002.jpeg in 1.74 seconds
# Processed 00019668_033226b444f744a798a886ed_step_000.jpeg in 3.42 seconds
# Processed 00019508_88bd6b02838b4b19a4bd63a1_step_005.jpeg in 1.54 seconds
# Processed 00013784_b49700a170944daeb25f24c4_step_003.jpeg in 1.25 seconds
# Processed 00017267_aa84fe632968433ba8bdee60_step_002.jpeg in 2.53 seconds
# Processed 00019608_3b26ad985f6341519f37cc80_step_003.jpeg in 3.10 seconds
# Processed 00010287_1f861fbd65f24b41836ca70f_step_011.jpeg in 1.24 seconds
# Processed 00017452_e5a4426e0fbf4088bec5c071_step_001.jpeg in 1.68 seconds
# Processed 00014014_e2e4dc4b16154551942a6570_step_000.jpeg in 2.03 seconds
# Processed 00019582_1ab2b043d54e48fa93a2c5d4_step_001.jpeg in 2.15 seconds
# Processed 00017537_462233e03ca64b68bf0ccd1b_step_023.jpeg in 1.85 seconds
# Processed 00015335_ef64e5a8aec64c9eaee43fb2_step_001.jpeg in 1.19 seconds
# Processed 00013086_9084b77631834dd584b2ac93_step_067.jpeg in 2.97 seconds
# Processed 00011050_9ae7b93932c448e9aaeb4849_step_004.jpeg in 2.03 seconds
# Processed 00010332_40594bc01ac04d3ebed3ff2b_step_002.jpeg in 4.38 seconds
# Processed 00016994_bc988dcf9a034d759fa21f3b_step_000.jpeg in 2.23 seconds
# Processed 00016878_8591c9420e234df2bad098db_step_000.jpeg in 1.81 seconds
# Processed: 100/2261
# Processed 00016282_ac681e0299b141a9a20e4b4f_step_003.jpeg in 2.32 seconds
# Processed 00015908_22809b6a019e412fb5ac3e70_step_000.jpeg in 1.35 seconds
# Processed 00014732_957177e368f14306ae253272_step_008.jpeg in 2.12 seconds
# Processed 00018185_2b8f5b4c462e40e6a282a8a3_step_003.jpeg in 1.36 seconds
# Processed 00011668_1ca1ad2a09504ff1bf83cf74_step_001.jpeg in 1.40 seconds
# Processed 00015788_bca56983eee140db9aa4c9a1_step_129.jpeg in 3.68 seconds
# Processed 00015436_3fcf9fa3a8c44c82bba5ef9f_step_004.jpeg in 3.58 seconds
# Processed 00012256_7b42647864e64240aed79cb6_step_001.jpeg in 1.52 seconds
# Processed 00016896_da114b2b328b4c5685b27e72_step_001.jpeg in 1.94 seconds
# Processed 00011559_26a622427a024bf3af381ee6_step_010.jpeg in 3.10 seconds
# Processed 00019775_3d7822b31cd4428d8abc99fd_step_001.jpeg in 1.33 seconds
# Processed 00017947_df3d85c7dc3e46b0b4e509a4_step_008.jpeg in 1.90 seconds
# Processed 00017033_0802ebdd812b44879a6a87ba_step_004.jpeg in 3.22 seconds
# Processed 00018760_e71e38347f254117b8876c5b_step_000.jpeg in 7.27 seconds
# Processed 00017518_462233e03ca64b68bf0ccd1b_step_004.jpeg in 1.81 seconds
# Processed 00013329_1ca7296c02f04a7dbc7af5f9_step_007.jpeg in 2.42 seconds
# Processed 00012638_4c0310460f1f43998e607ff3_step_001.jpeg in 1.20 seconds
# Processed 00014509_b5bcdf707bad4440813cf480_step_009.jpeg in 1.69 seconds
# Processed 00013065_9084b77631834dd584b2ac93_step_046.jpeg in 1.62 seconds
# Processed 00015610_08350e79f7604416a1126355_step_002.jpeg in 6.57 seconds
# Processed 00010419_9b261fc9c714449b93aab8ef_step_003.jpeg in 3.82 seconds
# Processed 00012083_bd0ba1071db44a4cb05e612c_step_018.jpeg in 1.96 seconds
# Processed 00012752_b17656deace54b61b3130c7e_step_017.jpeg in 3.84 seconds
# Processed 00017066_7bea1321c0da4c0cb8c1bad1_step_001.jpeg in 3.85 seconds
# Processed 00018313_a82487bb97f048b7849050a1_step_000.jpeg in 3.35 seconds
# Processed 00019298_4f873ff9d86a4429844503a3_step_011.jpeg in 7.81 seconds
# Processed 00014337_825f2362735943f49ab8fd09_step_000.jpeg in 1.50 seconds
# Processed 00015701_bca56983eee140db9aa4c9a1_step_042.jpeg in 1.88 seconds
# Processed 00015047_4d3a3befc86f475c86e135ad_step_001.jpeg in 2.06 seconds
# Processed 00014927_546d46eda4ab4b6eaafa2de4_step_014.jpeg in 2.30 seconds
# Processed 00018519_a370a1a5eadd4705870154a6_step_000.jpeg in 1.95 seconds
# Processed 00018368_be49704dcd3f463786c698e8_step_002.jpeg in 2.07 seconds
# Processed 00016799_d84732cbcd274c709c628f32_step_009.jpeg in 3.35 seconds
# Processed 00019558_6056f7a345e847e5ad7042b0_step_002.jpeg in 2.94 seconds
# Processed 00013711_b155d47caf984cc19abd7141_step_002.jpeg in 1.74 seconds
# Processed 00019998_7259f13b84f34cce843db1f8_step_041.jpeg in 2.06 seconds
# Processed 00014187_8f8cd005cda04a55a165c6d4_step_000.jpeg in 12.27 seconds
# Processed 00014090_5af82ffabaea4dbab3457fac_step_000.jpeg in 2.36 seconds
# Processed 00016626_d3741d99c39541118d6fbfaa_step_000.jpeg in 3.65 seconds
# Processed 00016450_3c2cb93146c44554bc36ecfd_step_006.jpeg in 1.69 seconds
# Processed 00017105_ab740a564cd74ed693e74191_step_000.jpeg in 2.40 seconds
# Processed 00019321_2c8cdebc68f14b2ba21ddd52_step_008.jpeg in 13.51 seconds
# Processed 00012264_eb932687cefd46ec9539dff8_step_001.jpeg in 2.55 seconds
# Processed 00013209_81a9bf47fde14020863c81e6_step_009.jpeg in 2.66 seconds
# Processed 00016279_ac681e0299b141a9a20e4b4f_step_000.jpeg in 1.67 seconds
# Processed 00017274_3a798f48c5e14264855de1d2_step_001.jpeg in 25.34 seconds
# Processed 00019489_c3009b533e43403489163a78_step_007.jpeg in 1.54 seconds
# Processed 00014419_e9f198927ff44079ad88cd1f_step_003.jpeg in 1.77 seconds
# Processed 00018438_c4b41fffa87e4a7fb2ffd226_step_002.jpeg in 2.18 seconds
# Processed 00018501_75fa8abd15754d45bcbf61b0_step_003.jpeg in 2.37 seconds
# Processed: 150/2261
# Processed 00017963_df3d85c7dc3e46b0b4e509a4_step_024.jpeg in 2.24 seconds
# Processed 00014936_546d46eda4ab4b6eaafa2de4_step_023.jpeg in 1.47 seconds
# Processed 00018075_6ecb4c42aa1541c8b5239d43_step_000.jpeg in 2.22 seconds
# Processed 00016796_d84732cbcd274c709c628f32_step_006.jpeg in 1.96 seconds
# Processed 00013198_73ddf59405a74e60b25aed40_step_000.jpeg in 1.36 seconds
# Processed 00019366_f8e6dc1f734043d9ba959963_step_000.jpeg in 3.58 seconds
# Processed 00011543_c97a02ca231847f1a6435241_step_012.jpeg in 1.73 seconds
# Processed 00014637_587e3c32948f4cfaaa61087c_step_000.jpeg in 1.91 seconds
# Processed 00017809_ee2e1cd6c7924d938393fccf_step_000.jpeg in 2.32 seconds
# Processed 00019592_b438474babc84034becd7d31_step_001.jpeg in 1.43 seconds
# Processed 00019356_39f94e23e474445ab3eba17c_step_006.jpeg in 2.21 seconds
# Processed 00016447_3c2cb93146c44554bc36ecfd_step_003.jpeg in 3.59 seconds
# Processed 00018204_9edb15538c774d709ba3a426_step_002.jpeg in 1.83 seconds
# Processed 00011678_1ca1ad2a09504ff1bf83cf74_step_011.jpeg in 1.98 seconds
# Processed 00017306_29f94b1d6eda4497bf50bcb4_step_000.jpeg in 1.69 seconds
# Processed 00016934_eb6717dfa4494c7588eb5888_step_009.jpeg in 1.54 seconds
# Processed 00013674_c282c0dc8b854445a32b9521_step_001.jpeg in 1.71 seconds
# Processed 00010455_2b3b86cd72de4b749cc012b2_step_005.jpeg in 1.26 seconds
# Processed 00018023_3ae8e6aba1764a938d05d216_step_046.jpeg in 1.47 seconds
# Processed 00012208_5e757983143143338fe9de8d_step_000.jpeg in 1.29 seconds
# Processed 00016284_ac681e0299b141a9a20e4b4f_step_005.jpeg in 1.82 seconds
# Processed 00019578_5418aab52e6846e79c7ec679_step_004.jpeg in 1.93 seconds
# Processed 00012442_568da81f27d0445a8f0f28bd_step_000.jpeg in 1.84 seconds
# Processed 00017163_1618b7fdf387415e8c9c01e9_step_001.jpeg in 2.40 seconds
# Processed 00019479_33bbd3c4dde946f6bed3011b_step_000.jpeg in 1.65 seconds
# Processed 00019439_03713b7964e348598c542318_step_039.jpeg in 1.63 seconds
# Processed 00016078_0941b79143d74d23a752dd44_step_002.jpeg in 2.53 seconds
# Processed 00017168_374df395f1434c2393c6a928_step_001.jpeg in 1.19 seconds
# Processed 00016694_5c9fb9684cd3419eb50febe2_step_004.jpeg in 1.43 seconds
# Processed 00016895_da114b2b328b4c5685b27e72_step_000.jpeg in 4.34 seconds
# Processed 00013904_034dd80b4af4447d8c515e71_step_000.jpeg in 3.39 seconds
# Processed 00011451_3d047e57c0004478bf9c9a51_step_011.jpeg in 1.82 seconds
# Processed 00017655_eb668aa8218f4cd09ac3a543_step_000.jpeg in 1.60 seconds
# Processed 00014242_53f4a634c7b54493a7fda450_step_001.jpeg in 1.81 seconds
# Processed 00017279_673b0fb6fe5648ada8dda0f6_step_002.jpeg in 1.52 seconds
# Processed 00014617_5e63aa2e67894cf7a38619d6_step_002.jpeg in 1.24 seconds
# Processed 00015791_bca56983eee140db9aa4c9a1_step_132.jpeg in 2.41 seconds
# Processed 00010779_8b2cd8a04a99446381446301_step_007.jpeg in 1.72 seconds
# Processed 00013901_859fe35d4719430d99b24783_step_000.jpeg in 1.43 seconds
# Processed 00015913_7198cd55d07e46f099dd757f_step_000.jpeg in 1.33 seconds
# Processed 00018217_78d53cedd6bf4e3387e416a9_step_000.jpeg in 1.50 seconds
# Processed 00010719_98644e6e040243568b190fb8_step_021.jpeg in 1.74 seconds
# Processed 00012972_73a1abe9b4b64673a4863322_step_000.jpeg in 1.81 seconds
# Processed 00016943_f58f1653a8294aa7812a0ca0_step_000.jpeg in 1.58 seconds
# Processed 00016190_195c8e28989a4913925e894c_step_003.jpeg in 5.88 seconds
# Processed 00012035_a005735a40fd4822a05509fd_step_002.jpeg in 2.37 seconds
# Processed 00017164_1618b7fdf387415e8c9c01e9_step_002.jpeg in 4.77 seconds
# Processed 00017021_aa4f8acbc96c46e7ae7cb5e6_step_004.jpeg in 3.19 seconds
# Processed 00015801_bca56983eee140db9aa4c9a1_step_142.jpeg in 2.49 seconds
# Processed 00011673_1ca1ad2a09504ff1bf83cf74_step_006.jpeg in 1.76 seconds
# Processed: 200/2261
# Processed 00018025_c018ffa180ad41ca92a6eba5_step_000.jpeg in 2.23 seconds
# Processed 00010007_7e4956ae07e24f6584127385_step_001.jpeg in 2.01 seconds
# Processed 00017457_28a7687e4fae472399c06676_step_000.jpeg in 15.03 seconds
# Processed 00015051_4d3a3befc86f475c86e135ad_step_005.jpeg in 4.23 seconds
# Processed 00016709_c9a84a2e7dab47b79f347c14_step_000.jpeg in 1.99 seconds
# Processed 00012719_8998b0e9a2d944a3b991e52d_step_001.jpeg in 2.41 seconds
# Processed 00010771_dc88b4bc837847ce8102c53a_step_000.jpeg in 1.88 seconds
# Processed 00017739_5370326b3d7b40f48d9b3be1_step_007.jpeg in 1.65 seconds
# Processed 00013936_dbbc429e72ea48c5bb0b1fcd_step_014.jpeg in 2.33 seconds
# Processed 00017779_5370326b3d7b40f48d9b3be1_step_047.jpeg in 3.82 seconds
# Processed 00014323_cc69b3179a764cdc9f7464db_step_000.jpeg in 1.30 seconds
# Processed 00013166_b80e2a1d85a645ccb9a18d1f_step_001.jpeg in 1.67 seconds
# Processed 00019680_e1f53cb1e07d4b3184a50868_step_000.jpeg in 1.57 seconds
# Processed 00016825_eb9df9dcacfc47f5b9e54b8e_step_005.jpeg in 1.51 seconds
# Processed 00015703_bca56983eee140db9aa4c9a1_step_044.jpeg in 1.38 seconds
# Processed 00012841_fead43fe3c4947669b303168_step_007.jpeg in 1.62 seconds
# Processed 00017458_28a7687e4fae472399c06676_step_001.jpeg in 0.94 seconds
# Processed 00015250_3da57e15a38446c8ab00fa3c_step_000.jpeg in 1.67 seconds
# Processed 00017514_462233e03ca64b68bf0ccd1b_step_000.jpeg in 1.96 seconds
# Processed 00013312_fc91ed8d38d6414dac3b00dc_step_000.jpeg in 2.19 seconds
# Processed 00013432_97afc606ba8d4cfdae7a4885_step_006.jpeg in 1.64 seconds
# Processed 00013923_dbbc429e72ea48c5bb0b1fcd_step_001.jpeg in 1.80 seconds
# Processed 00010155_ccef4063b69f428e91b498c9_step_000.jpeg in 1.80 seconds
# Processed 00018523_095668f185bd444eb726077e_step_000.jpeg in 1.82 seconds
# Processed 00016945_f58f1653a8294aa7812a0ca0_step_002.jpeg in 1.29 seconds
# Processed 00018378_6a88c6c0476244b7bddd0882_step_006.jpeg in 2.53 seconds
# Processed 00014117_acca1a25478e40799086fe24_step_000.jpeg in 1.32 seconds
# Processed 00017744_5370326b3d7b40f48d9b3be1_step_012.jpeg in 1.33 seconds
# Processed 00019000_5659e986d2e44d2e85f765f1_step_011.jpeg in 1.64 seconds
# Processed 00018759_dc01e153c03e4c689df1cfcf_step_000.jpeg in 1.40 seconds
# Processed 00014194_8f8cd005cda04a55a165c6d4_step_007.jpeg in 1.94 seconds
# Processed 00019929_9005f32fe12949e796db0dee_step_000.jpeg in 1.08 seconds
# Processed 00018413_6a88c6c0476244b7bddd0882_step_041.jpeg in 1.61 seconds
# Processed 00017713_ed02868cc86f4ab285b5cc5d_step_002.jpeg in 2.19 seconds
# Processed 00018366_be49704dcd3f463786c698e8_step_000.jpeg in 1.14 seconds
# Processed 00014777_b0d4594df299459698e07294_step_001.jpeg in 1.29 seconds
# Processed 00012055_370f527733f24f86b29d0c4a_step_002.jpeg in 1.96 seconds
# Processed 00012070_bd0ba1071db44a4cb05e612c_step_005.jpeg in 1.56 seconds
# Processed 00019023_52a34dc6c76842228bccadaf_step_006.jpeg in 1.59 seconds
# Processed 00016428_870713e0627d43b0a2e0a874_step_000.jpeg in 1.81 seconds
# Processed 00014756_2df7751fcb7c469caba603db_step_004.jpeg in 3.68 seconds
# Processed 00018334_5f57a79f487542708225158b_step_000.jpeg in 1.80 seconds
# Processed 00015630_221136f8c52747b4bd0b405a_step_001.jpeg in 2.00 seconds
# Processed 00011674_1ca1ad2a09504ff1bf83cf74_step_007.jpeg in 1.85 seconds
# Processed 00018954_b302da1a26764dd0afcd55ff_step_082.jpeg in 2.47 seconds
# Processed 00011677_1ca1ad2a09504ff1bf83cf74_step_010.jpeg in 1.57 seconds
# Processed 00018309_fc57e42efad343c2a4bc0886_step_000.jpeg in 1.55 seconds
# Processed 00014007_0b69e5a8fb4148e28da7670c_step_000.jpeg in 1.54 seconds
# Processed 00018363_f169e07b3ae8461d80c7bf46_step_000.jpeg in 1.73 seconds
# Processed 00013476_c204b69b8498479097597944_step_001.jpeg in 1.52 seconds
# Processed: 250/2261
# Processed 00016416_a493c115c0124aa3b378693e_step_000.jpeg in 1.83 seconds
# Processed 00014941_546d46eda4ab4b6eaafa2de4_step_028.jpeg in 2.27 seconds
# Processed 00013928_dbbc429e72ea48c5bb0b1fcd_step_006.jpeg in 1.87 seconds
# Processed 00017309_29f94b1d6eda4497bf50bcb4_step_003.jpeg in 2.86 seconds
# Processed 00017176_5bdeec5a25ed46488519ef60_step_000.jpeg in 2.37 seconds
# Processed 00018428_542a5f30ab4e42a591512d71_step_000.jpeg in 1.70 seconds
# Processed 00012965_776bd560aff34c5584f97309_step_000.jpeg in 1.83 seconds
# Processed 00018968_b302da1a26764dd0afcd55ff_step_096.jpeg in 1.52 seconds
# Processed 00011164_db6e2de6f4ae4ec493ebe2aa_step_040.jpeg in 2.06 seconds
# Processed 00013604_312af7b545374a688a43c5f8_step_010.jpeg in 1.91 seconds
# Processed 00017158_6d67f7e9138241b9ac13beef_step_002.jpeg in 1.66 seconds
# Processed 00013302_68eb44ebd3f74c1399af56d8_step_000.jpeg in 1.70 seconds
# Processed 00014164_9b15e0ea3daa4158a923b32f_step_001.jpeg in 1.57 seconds
# Processed 00019540_c1eebdfc2bb44e1199f86482_step_001.jpeg in 1.44 seconds
# Processed 00011358_3890a2529eac4756904b0156_step_002.jpeg in 2.66 seconds
# Processed 00019074_afa5aa113a3d4adc89c675b7_step_000.jpeg in 1.69 seconds
# Processed 00018188_2b8f5b4c462e40e6a282a8a3_step_006.jpeg in 2.41 seconds
# Processed 00015819_bca56983eee140db9aa4c9a1_step_160.jpeg in 1.67 seconds
# Processed 00015941_4fee03e6762d4fefaa49c3d5_step_007.jpeg in 2.19 seconds
# Processed 00017215_f2dc1f4915174a18b9c18836_step_000.jpeg in 2.14 seconds
# Processed 00014309_edaea9d5b31d401cab6f50ef_step_006.jpeg in 1.84 seconds
# Processed 00011867_73c6505f827541168d5410e4_step_136.jpeg in 2.11 seconds
# Processed 00011178_db6e2de6f4ae4ec493ebe2aa_step_054.jpeg in 3.18 seconds
# Processed 00011671_1ca1ad2a09504ff1bf83cf74_step_004.jpeg in 1.75 seconds
# Processed 00018170_96e828d6da0641999cc17f60_step_000.jpeg in 1.66 seconds
# Processed 00017151_e530c23f7c0f415bb2a5c937_step_001.jpeg in 2.22 seconds
# Processed 00017683_51d911b5e6334422b871b89e_step_000.jpeg in 4.13 seconds
# Processed 00019969_7259f13b84f34cce843db1f8_step_012.jpeg in 1.43 seconds
# Processed 00014913_546d46eda4ab4b6eaafa2de4_step_000.jpeg in 1.18 seconds
# Processed 00015902_a1f567172ebc400f9dadc640_step_000.jpeg in 1.57 seconds
# Processed 00019710_80e0b5b4bb5d4bbab04a8621_step_002.jpeg in 1.79 seconds
# Processed 00018989_5659e986d2e44d2e85f765f1_step_000.jpeg in 1.30 seconds
# Processed 00014733_957177e368f14306ae253272_step_009.jpeg in 1.70 seconds
# Processed 00012268_eb932687cefd46ec9539dff8_step_005.jpeg in 1.69 seconds
# Processed 00014557_42c1295a915f4fe580b4bd32_step_000.jpeg in 1.66 seconds
# Processed 00017746_5370326b3d7b40f48d9b3be1_step_014.jpeg in 2.09 seconds
# Processed 00012041_1e36911fd14e461595cd0864_step_000.jpeg in 1.43 seconds
# Processed 00016603_3d6966cd42eb44ab8f4224f2_step_143.jpeg in 1.62 seconds
# Processed 00011580_26a622427a024bf3af381ee6_step_031.jpeg in 1.37 seconds
# Processed 00017823_b82ec46a8af04dd5af47890c_step_001.jpeg in 2.10 seconds
# Processed 00012482_f523ba0f4b4d4a8fbce396f4_step_006.jpeg in 1.48 seconds
# Processed 00019762_0690e6ee4e694caf996306b3_step_003.jpeg in 1.97 seconds
# Processed 00013532_702ff5b78e964c93a765bd5d_step_000.jpeg in 1.66 seconds
# Processed 00013447_64f1e17b08b142d8886288bd_step_004.jpeg in 1.48 seconds
# Processed 00017073_654ff1cd5dd045e890e73807_step_001.jpeg in 2.52 seconds
# Processed 00017610_410be2bba5a44473ab723de3_step_055.jpeg in 1.86 seconds
# Processed 00019326_80a754290fb446c085b20544_step_000.jpeg in 2.69 seconds
# Processed 00017607_410be2bba5a44473ab723de3_step_052.jpeg in 2.34 seconds
# Processed 00012088_bd0ba1071db44a4cb05e612c_step_023.jpeg in 1.87 seconds
# Processed 00017961_df3d85c7dc3e46b0b4e509a4_step_022.jpeg in 1.72 seconds
# Processed: 300/2261
# Processed 00012163_41b99f25ba5b453391c2b958_step_004.jpeg in 2.08 seconds
# Processed 00015443_c32d61749e2549559b592580_step_000.jpeg in 2.13 seconds
# Processed 00014939_546d46eda4ab4b6eaafa2de4_step_026.jpeg in 1.75 seconds
# Processed 00014128_1e62e6a00c454e41866efa0d_step_002.jpeg in 2.10 seconds
# Processed 00011170_db6e2de6f4ae4ec493ebe2aa_step_046.jpeg in 2.53 seconds
# Processed 00014932_546d46eda4ab4b6eaafa2de4_step_019.jpeg in 1.79 seconds
# Processed 00015824_bca56983eee140db9aa4c9a1_step_165.jpeg in 1.66 seconds
# Processed 00016704_429bc6061d8c417eb4804f0e_step_000.jpeg in 2.30 seconds
# Processed 00014639_587e3c32948f4cfaaa61087c_step_002.jpeg in 1.47 seconds
# Processed 00011185_db6e2de6f4ae4ec493ebe2aa_step_061.jpeg in 2.01 seconds
# Processed 00012360_ea88a31737c44e5ba7d7fd91_step_000.jpeg in 1.83 seconds
# Processed 00016430_2afe53d409bd42ba91843ef8_step_000.jpeg in 1.39 seconds
# Processed 00016944_f58f1653a8294aa7812a0ca0_step_001.jpeg in 1.44 seconds
# Processed 00014255_6bfa94bd4fc942e7a0300992_step_005.jpeg in 1.67 seconds
# Processed 00011083_fddd53ce45f640f3ab922328_step_018.jpeg in 2.25 seconds
# Processed 00010240_1b6914b4eb444fc6ac3df76a_step_008.jpeg in 2.38 seconds
# Processed 00015310_aea9a61c5bb845dc8bed4452_step_011.jpeg in 1.56 seconds
# Processed 00012300_b68acac41f4544649f98778c_step_002.jpeg in 2.30 seconds
# Processed 00012778_18c48443ac37475293020e0b_step_002.jpeg in 1.43 seconds
# Processed 00015038_2c8658a98ac64a9d936d516b_step_000.jpeg in 1.53 seconds
# Processed 00014245_6f3f77de8dc8485ca2cbc68e_step_000.jpeg in 1.79 seconds
# Processed 00017643_28ef8351018b4be18377fa7b_step_015.jpeg in 1.80 seconds
# Processed 00017932_221c91e754324a458278b93e_step_000.jpeg in 1.66 seconds
# Processed 00013064_9084b77631834dd584b2ac93_step_045.jpeg in 1.85 seconds
# Processed 00016255_79b106069c9a4df4b62b9078_step_003.jpeg in 2.03 seconds
# Processed 00018615_423ab08382b847da96d9ff89_step_040.jpeg in 2.00 seconds
# Processed 00017747_5370326b3d7b40f48d9b3be1_step_015.jpeg in 1.69 seconds
# Processed 00014950_546d46eda4ab4b6eaafa2de4_step_037.jpeg in 1.54 seconds
# Processed 00017850_08893609d30e453493c4c079_step_025.jpeg in 2.69 seconds
# Processed 00013083_9084b77631834dd584b2ac93_step_064.jpeg in 2.01 seconds
# Processed 00015381_a5e39f3829f24e998d5f1c69_step_002.jpeg in 2.03 seconds
# Processed 00016899_da114b2b328b4c5685b27e72_step_004.jpeg in 4.71 seconds
# Processed 00011351_0a10c1155e434f5d9edeb0f0_step_004.jpeg in 1.90 seconds
# Processed 00014530_41035cff7f614790ae0fb9c0_step_006.jpeg in 1.81 seconds
# Processed 00015724_bca56983eee140db9aa4c9a1_step_065.jpeg in 3.39 seconds
# Processed 00017061_c0b86cb843784f7db8dfeb08_step_002.jpeg in 2.87 seconds
# Processed 00012298_b68acac41f4544649f98778c_step_000.jpeg in 2.51 seconds
# Processed 00011082_fddd53ce45f640f3ab922328_step_017.jpeg in 2.15 seconds
# Processed 00012435_a8cc9321a5eb46b695735d06_step_003.jpeg in 1.36 seconds
# Processed 00010661_d4555389310c42d98d45f8bd_step_004.jpeg in 2.69 seconds
# Processed 00017071_0dc34aac682b414bba08ec46_step_000.jpeg in 2.41 seconds
# Processed 00013602_312af7b545374a688a43c5f8_step_008.jpeg in 2.20 seconds
# Processed 00019812_cd8b3c68980a4902848adef4_step_000.jpeg in 2.06 seconds
# Processed 00018513_26ba3994974941c3ab132a69_step_006.jpeg in 2.69 seconds
# Processed 00013539_f1ecb4be0c4a4f89860c47e6_step_000.jpeg in 3.07 seconds
# Processed 00015451_bf6b4f6b734848239d7170a0_step_000.jpeg in 2.16 seconds
# Processed 00011249_3daf0773bdde4b72a1459f3e_step_007.jpeg in 2.68 seconds
# Processed 00019791_a2024e9c447942808db6fe70_step_000.jpeg in 2.34 seconds
# Processed 00019934_8e8f4031fef04789ae887642_step_000.jpeg in 2.27 seconds
# Processed 00016280_ac681e0299b141a9a20e4b4f_step_001.jpeg in 3.45 seconds
# Processed: 350/2261
# Processed 00017930_752778aeefb145dfb73e1e5c_step_000.jpeg in 2.93 seconds
# Processed 00017336_7b4b171969484b22bd187d54_step_001.jpeg in 1.68 seconds
# Processed 00019436_03713b7964e348598c542318_step_036.jpeg in 1.83 seconds
# Processed 00017837_08893609d30e453493c4c079_step_012.jpeg in 3.05 seconds
# Processed 00010470_71e55f391b054d258d68f256_step_000.jpeg in 1.61 seconds
# Processed 00019698_f5ac8d924e88451ba0106250_step_002.jpeg in 1.66 seconds
# Processed 00019954_dfa055c9e97f4c798f760136_step_001.jpeg in 3.33 seconds
# Processed 00018035_44e70ceec2ce4ca5a4712c4a_step_000.jpeg in 4.30 seconds
# Processed 00018228_33589607f2d24e88b111ccea_step_000.jpeg in 2.38 seconds
# Processed 00017403_8ebc7bd3c3af451485dd012b_step_000.jpeg in 2.61 seconds
# Processed 00013073_9084b77631834dd584b2ac93_step_054.jpeg in 2.79 seconds
# Processed 00019476_36f0d3351c094ee7bf3e0bd5_step_005.jpeg in 1.31 seconds
# Processed 00013296_7ade8120ae164f42bf65d907_step_004.jpeg in 2.16 seconds
# Processed 00010179_f91d806ac1e34ea1b14e23be_step_000.jpeg in 2.48 seconds
# Processed 00010654_a5113b6a40514d74802d96c7_step_002.jpeg in 5.77 seconds
# Processed 00010716_98644e6e040243568b190fb8_step_018.jpeg in 1.18 seconds
# Processed 00019234_1bcd132f82c84761b4e9851d_step_032.jpeg in 2.11 seconds
# Processed 00010019_4e3281f2d3864f2696f1e298_step_000.jpeg in 1.65 seconds
# Processed 00014139_ff252da9ce324bd095481d6d_step_003.jpeg in 2.12 seconds
# Processed 00017700_f847dfc5deef43049f1fe9f2_step_001.jpeg in 1.85 seconds
# Processed 00016679_ec83dcf6043b482994971e44_step_000.jpeg in 1.82 seconds
# Processed 00015034_5fac1029c28e4c78ab7755c2_step_000.jpeg in 2.39 seconds
# Processed 00011603_c087f04c99464bf7ab2380c4_step_001.jpeg in 2.26 seconds
# Processed 00016905_d76e932aa19c40d49c6ed2f6_step_000.jpeg in 1.99 seconds
# Processed 00019717_27c6b36c62cc4841a9663454_step_000.jpeg in 1.83 seconds
# Processed 00019911_f97c002abbfe448d8111d962_step_006.jpeg in 2.07 seconds
# Processed 00012506_26992d92f41141008de4b854_step_002.jpeg in 2.20 seconds
# Processed 00012623_5708da2113be43c0b783f01f_step_000.jpeg in 1.46 seconds
# Processed 00018749_7d30bf25e190406f96974a5e_step_000.jpeg in 2.75 seconds
# Processed 00015457_f8e87729e5cc4d4d81cbeb70_step_002.jpeg in 2.00 seconds
# Processed 00014943_546d46eda4ab4b6eaafa2de4_step_030.jpeg in 2.15 seconds
# Processed 00013606_312af7b545374a688a43c5f8_step_012.jpeg in 2.06 seconds
# Processed 00016932_eb6717dfa4494c7588eb5888_step_007.jpeg in 1.95 seconds
# Processed 00015850_bca56983eee140db9aa4c9a1_step_191.jpeg in 1.63 seconds
# Processed 00013295_7ade8120ae164f42bf65d907_step_003.jpeg in 3.76 seconds
# Processed 00018474_dd34c3ffed5c4021abdefc49_step_003.jpeg in 1.41 seconds
# Processed 00016917_b78bc7868554452495c67848_step_000.jpeg in 1.74 seconds
# Processed 00017721_2530e0f7fb844685b208c165_step_000.jpeg in 2.27 seconds
# Processed 00012255_7b42647864e64240aed79cb6_step_000.jpeg in 1.63 seconds
# Processed 00017727_2c3f8a729f09498990275838_step_000.jpeg in 3.15 seconds
# Processed 00019138_cb329821de4647afa6accad6_step_003.jpeg in 2.25 seconds
# Processed 00019150_71752f2bc5bc4c6388aece57_step_003.jpeg in 1.72 seconds
# Processed 00014937_546d46eda4ab4b6eaafa2de4_step_024.jpeg in 1.64 seconds
# Processed 00013759_8f0c1e5ff3d2493dbcec3857_step_016.jpeg in 2.70 seconds
# Processed 00017848_08893609d30e453493c4c079_step_023.jpeg in 1.98 seconds
# Processed 00017644_28ef8351018b4be18377fa7b_step_016.jpeg in 2.12 seconds
# Processed 00017805_4a9bec0fd5eb4c95ab79f33a_step_000.jpeg in 1.98 seconds
# Processed 00018147_e732ea9d54f94ffc91f3ac7e_step_000.jpeg in 1.69 seconds
# Processed 00010398_3f8b98f0e6b84352819ef9b2_step_001.jpeg in 2.28 seconds
# Processed 00017945_df3d85c7dc3e46b0b4e509a4_step_006.jpeg in 2.11 seconds
# Processed: 400/2261
# Processed 00012921_97d657f2bd0543ccbaad325c_step_071.jpeg in 1.90 seconds
# Processed 00013601_312af7b545374a688a43c5f8_step_007.jpeg in 1.66 seconds
# Processed 00018127_bc8ab2012b6b458c9e2fedf2_step_005.jpeg in 3.18 seconds
# Processed 00016479_3d6966cd42eb44ab8f4224f2_step_019.jpeg in 1.99 seconds
# Processed 00011484_547fd4f9ecd74f86ba27d0c7_step_000.jpeg in 2.38 seconds
# Processed 00017290_8bebb1d1f076444d9c90e7e6_step_000.jpeg in 1.69 seconds
# Processed 00016045_0cdbe005df6e43fa96669fe8_step_002.jpeg in 2.24 seconds
# Processed 00017388_2377343d844e423d880db8c8_step_000.jpeg in 1.69 seconds
# Processed 00016659_f9903edd12114483861d3546_step_003.jpeg in 2.59 seconds
# Processed 00014429_204e862df9c94a77bb4a582e_step_000.jpeg in 6.16 seconds
# Processed 00017878_451e392e4b024219be45de7c_step_000.jpeg in 1.53 seconds
# Processed 00016790_d84732cbcd274c709c628f32_step_000.jpeg in 1.60 seconds
# Processed 00011353_0a10c1155e434f5d9edeb0f0_step_006.jpeg in 4.39 seconds
# Processed 00017666_afda8637b9ce49f88eeb0443_step_000.jpeg in 5.53 seconds
# Processed 00018415_6a88c6c0476244b7bddd0882_step_043.jpeg in 2.24 seconds
# Processed 00017903_1e6d5c1efd344b148e5b02a7_step_002.jpeg in 1.51 seconds
# Processed 00014960_abe8364fa3c84ca28e1e504b_step_000.jpeg in 2.92 seconds
# Processed 00013226_7d22ab74d8e9494a9d583a5d_step_007.jpeg in 2.87 seconds
# Processed 00014195_ed1eacbea54d402d96ea39f1_step_000.jpeg in 2.30 seconds
# Processed 00019140_eea40785089c4b7885a21add_step_001.jpeg in 1.48 seconds
# Processed 00014938_546d46eda4ab4b6eaafa2de4_step_025.jpeg in 1.89 seconds
# Processed 00013692_4e525fcfdb0b458fbe78eff7_step_001.jpeg in 4.65 seconds
# Processed 00019921_ada0ecf751ff431497ff1d03_step_002.jpeg in 1.70 seconds
# Processed 00018385_6a88c6c0476244b7bddd0882_step_013.jpeg in 1.59 seconds
# Processed 00016034_43a50a9b5e124c85bedbcb99_step_002.jpeg in 2.18 seconds
# Processed 00018537_056ee70d3bd2402ebc162b9c_step_001.jpeg in 1.30 seconds
# Processed 00016300_f4c1172ee23d4a3793ffe39a_step_007.jpeg in 0.97 seconds
# Processed 00011414_3d376f30a932449babb6f295_step_007.jpeg in 2.40 seconds
# Processed 00015491_548f0b75c2394435981f91dc_step_000.jpeg in 1.41 seconds
# Processed 00017815_112e2077b37a466fb05361b1_step_000.jpeg in 1.66 seconds
# Processed 00019590_ad256b6c035a448eaa7ad218_step_000.jpeg in 1.88 seconds
# Processed 00013732_4dd36120a2b946deb2207db2_step_001.jpeg in 1.68 seconds
# Processed 00010616_361c9786cd894debb4689c63_step_013.jpeg in 2.14 seconds
# Processed 00019075_cb9ab396ada246bda1a33d8f_step_000.jpeg in 2.20 seconds
# Processed 00014481_04d0b45e8f344dd7a549f6de_step_000.jpeg in 1.37 seconds
# Processed 00011344_3050e87f10584fd6a9ca17e9_step_000.jpeg in 1.06 seconds
# Processed 00016760_86a5a4fd65ba409cba91c4a7_step_001.jpeg in 1.66 seconds
# Processed 00013565_fec5fa6ad9244aaeb0f53daa_step_000.jpeg in 2.10 seconds
# Processed 00018001_3ae8e6aba1764a938d05d216_step_024.jpeg in 1.92 seconds
# Processed 00013758_8f0c1e5ff3d2493dbcec3857_step_015.jpeg in 1.83 seconds
# Processed 00013018_e17759b820954b9885946440_step_000.jpeg in 2.09 seconds
# Processed 00010408_3f8b98f0e6b84352819ef9b2_step_011.jpeg in 2.04 seconds
# Processed 00017864_08893609d30e453493c4c079_step_039.jpeg in 1.78 seconds
# Processed 00017642_28ef8351018b4be18377fa7b_step_014.jpeg in 1.84 seconds
# Processed 00012644_4c0310460f1f43998e607ff3_step_007.jpeg in 2.53 seconds
# Processed 00017934_9fa7e542014342329d8a21fc_step_001.jpeg in 3.69 seconds
# Processed 00012897_97d657f2bd0543ccbaad325c_step_047.jpeg in 1.91 seconds
# Processed 00014538_d2e4a69c30d24991b44b2e6a_step_000.jpeg in 0.97 seconds
# Processed 00016766_d30ac878a86045768385e229_step_000.jpeg in 1.49 seconds
# Processed 00012640_4c0310460f1f43998e607ff3_step_003.jpeg in 2.26 seconds
# Processed: 450/2261
# Processed 00019686_9095050bde294d09b9e00e1c_step_000.jpeg in 1.50 seconds
# Processed 00017698_8b08a995ff574064b2fdd2ea_step_000.jpeg in 1.51 seconds
# Processed 00016930_eb6717dfa4494c7588eb5888_step_005.jpeg in 1.08 seconds
# Processed 00016772_3c41192f831a4979a90c0bb9_step_004.jpeg in 1.28 seconds
# Processed 00011920_92fcadd1354f48adbc306416_step_000.jpeg in 1.65 seconds
# Processed 00011490_547fd4f9ecd74f86ba27d0c7_step_006.jpeg in 1.25 seconds
# Processed 00011314_c10fb70115884d70bc90d671_step_003.jpeg in 2.18 seconds
# Processed 00018361_73fb4814fc144c37ba98dd99_step_000.jpeg in 2.26 seconds
# Processed 00010698_98644e6e040243568b190fb8_step_000.jpeg in 2.37 seconds
# Processed 00010508_71e55f391b054d258d68f256_step_038.jpeg in 1.60 seconds
# Processed 00013245_c8e66e64d5d9474c8ac8c02b_step_000.jpeg in 1.20 seconds
# Processed 00013757_8f0c1e5ff3d2493dbcec3857_step_014.jpeg in 2.15 seconds
# Processed 00018213_7d2ee72812984c4196cda9b7_step_000.jpeg in 6.79 seconds
# Processed 00016705_429bc6061d8c417eb4804f0e_step_001.jpeg in 4.84 seconds
# Processed 00011013_9d086bb83b934224a3460726_step_001.jpeg in 6.18 seconds
# Processed 00011689_1ca1ad2a09504ff1bf83cf74_step_022.jpeg in 1.82 seconds
# Processed 00016445_3c2cb93146c44554bc36ecfd_step_001.jpeg in 2.67 seconds
# Processed 00013924_dbbc429e72ea48c5bb0b1fcd_step_002.jpeg in 2.91 seconds
# Processed 00013304_68eb44ebd3f74c1399af56d8_step_002.jpeg in 2.14 seconds
# Processed 00014596_46cf08f6f2db48499012d17b_step_000.jpeg in 1.76 seconds
# Processed 00018550_55b42d1f16024d448636f81b_step_000.jpeg in 1.70 seconds
# Processed 00019338_f73158242bb343449dd11920_step_000.jpeg in 2.15 seconds
# Processed 00012350_1c45fd4ae2794a0da05a3958_step_000.jpeg in 2.63 seconds
# Processed 00017741_5370326b3d7b40f48d9b3be1_step_009.jpeg in 1.11 seconds
# Processed 00019521_aa2a6684d2b24d99ac7d2ef2_step_000.jpeg in 2.82 seconds
# Processed 00016260_9c39ab573b4c4f4887619242_step_000.jpeg in 1.69 seconds
# Processed 00014318_edaea9d5b31d401cab6f50ef_step_015.jpeg in 1.94 seconds
# Processed 00016931_eb6717dfa4494c7588eb5888_step_006.jpeg in 1.90 seconds
# Processed 00015870_c99e23b9d32845b2b29aaf99_step_003.jpeg in 2.58 seconds
# Processed 00014371_4898b9df95db421ca3eeae4d_step_000.jpeg in 1.08 seconds
# Processed 00017936_193cdfb2b7b048f582636d34_step_000.jpeg in 2.30 seconds
# Processed 00017574_410be2bba5a44473ab723de3_step_019.jpeg in 2.38 seconds
# Processed 00019650_a25746661f4b47d88477547b_step_004.jpeg in 2.81 seconds
# Processed 00015311_aea9a61c5bb845dc8bed4452_step_012.jpeg in 2.22 seconds
# Processed 00010527_a8adf76bfb3d4789996949d7_step_003.jpeg in 2.58 seconds
# Processed 00017297_20bf2c1b9999444785baa949_step_001.jpeg in 2.40 seconds
# Processed 00012042_1e36911fd14e461595cd0864_step_001.jpeg in 2.64 seconds
# Processed 00010201_d9c6183e3eb4478bb0d9c543_step_006.jpeg in 2.94 seconds
# Processed 00014925_546d46eda4ab4b6eaafa2de4_step_012.jpeg in 1.70 seconds
# Processed 00015751_bca56983eee140db9aa4c9a1_step_092.jpeg in 2.07 seconds
# Processed 00017251_6dc0b403ea624faf916cdfdf_step_000.jpeg in 2.53 seconds
# Processed 00010789_297b35a722ab47519729e8f4_step_002.jpeg in 1.87 seconds
# Processed 00017519_462233e03ca64b68bf0ccd1b_step_005.jpeg in 1.57 seconds
# Processed 00019587_ad28e04c3841472ca6179821_step_002.jpeg in 1.98 seconds
# Processed 00018658_eb344387745a40edb0d7913b_step_036.jpeg in 2.11 seconds
# Processed 00013617_a0648633be634b2f8e7e804a_step_000.jpeg in 2.53 seconds
# Processed 00017042_0802ebdd812b44879a6a87ba_step_013.jpeg in 1.93 seconds
# Processed 00013372_878b790870f64e228c88a6c6_step_016.jpeg in 2.14 seconds
# Processed 00015813_bca56983eee140db9aa4c9a1_step_154.jpeg in 1.72 seconds
# Processed 00018099_80d9eb75541744048dcceb65_step_013.jpeg in 1.50 seconds
# Processed: 500/2261
# Processed 00019888_6ecd40b59a5541fcb4b139cf_step_001.jpeg in 1.95 seconds
# Processed 00015743_bca56983eee140db9aa4c9a1_step_084.jpeg in 1.53 seconds
# Processed 00014763_2df7751fcb7c469caba603db_step_011.jpeg in 5.53 seconds
# Processed 00015635_c84b082d6b1a48d39991715f_step_000.jpeg in 2.99 seconds
# Processed 00011696_1ca1ad2a09504ff1bf83cf74_step_029.jpeg in 2.04 seconds
# Processed 00017477_72c836d428f94a42bf9b0c5e_step_001.jpeg in 1.77 seconds
# Processed 00017107_ab740a564cd74ed693e74191_step_002.jpeg in 1.79 seconds
# Processed 00013264_fcffe5c84c4d486986b5b9da_step_000.jpeg in 1.66 seconds
# Processed 00015847_bca56983eee140db9aa4c9a1_step_188.jpeg in 1.16 seconds
# Processed 00010070_493cf58028d24a5b97528c11_step_000.jpeg in 2.07 seconds
# Processed 00012372_eeadb988241143978ce0f238_step_002.jpeg in 1.74 seconds
# Processed 00017312_e00e1c4c808a4533a8c264d5_step_001.jpeg in 1.54 seconds
# Processed 00017789_1f461b7cc66f48b88b57477b_step_002.jpeg in 1.73 seconds
# Processed 00011627_c4d731b0b8484b3783981916_step_000.jpeg in 1.29 seconds
# Processed 00014582_220e53490a4b42fbb4970b62_step_000.jpeg in 1.36 seconds
# Processed 00015812_bca56983eee140db9aa4c9a1_step_153.jpeg in 1.87 seconds
# Processed 00017507_477ea6d4d5f743159185b7f9_step_006.jpeg in 1.13 seconds
# Processed 00016865_72dc88316f754a8da10bd3f0_step_005.jpeg in 1.63 seconds
# Processed 00011913_73c6505f827541168d5410e4_step_182.jpeg in 0.94 seconds
# Processed 00015235_6d7bb8d6b5904c1f8251b199_step_003.jpeg in 1.73 seconds
# Processed 00019520_d688b79572664201a001f90b_step_000.jpeg in 1.53 seconds
# Processed 00019490_2bc9b6eb75104ce8b7189fad_step_000.jpeg in 1.60 seconds
# Processed 00015702_bca56983eee140db9aa4c9a1_step_043.jpeg in 1.96 seconds
# Processed 00016189_195c8e28989a4913925e894c_step_002.jpeg in 1.91 seconds
# Processed 00012142_8e010d877c9c462fa05ec374_step_000.jpeg in 1.56 seconds
# Processed 00019780_876f6f33911b43d690f756d7_step_000.jpeg in 2.51 seconds
# Processed 00010397_3f8b98f0e6b84352819ef9b2_step_000.jpeg in 2.64 seconds
# Processed 00018299_9297b1ecf4c34344b1f29459_step_000.jpeg in 2.00 seconds
# Processed 00018041_3f36fcb1e2ce4e7ba9160573_step_001.jpeg in 2.33 seconds
# Processed 00010759_4d71e0e2a0d44751bf61790d_step_001.jpeg in 1.89 seconds
# Processed 00015631_221136f8c52747b4bd0b405a_step_002.jpeg in 2.48 seconds
# Processed 00014080_6ba1e39775d942b78b0c84f1_step_001.jpeg in 1.64 seconds
# Processed 00017400_bfcf40fca9644fbcb05a23fb_step_000.jpeg in 2.60 seconds
# Processed 00018480_953882c8af1140989f20b9dd_step_002.jpeg in 1.57 seconds
# Processed 00017302_902d17dfbf2043188fcbb604_step_000.jpeg in 3.90 seconds
# Processed 00011866_73c6505f827541168d5410e4_step_135.jpeg in 2.90 seconds
# Processed 00012892_97d657f2bd0543ccbaad325c_step_042.jpeg in 1.06 seconds
# Processed 00015300_aea9a61c5bb845dc8bed4452_step_001.jpeg in 2.18 seconds
# Processed 00019651_a25746661f4b47d88477547b_step_005.jpeg in 2.77 seconds
# Processed 00019607_3b26ad985f6341519f37cc80_step_002.jpeg in 2.31 seconds
# Processed 00019437_03713b7964e348598c542318_step_037.jpeg in 1.59 seconds
# Processed 00017553_456e4c42a9d642a5b26d5f09_step_000.jpeg in 3.96 seconds
# Processed 00011676_1ca1ad2a09504ff1bf83cf74_step_009.jpeg in 1.11 seconds
# Processed 00017224_e215db589d7b4e76942a2661_step_001.jpeg in 1.33 seconds
# Processed 00017328_f72a043c29a74086996085d3_step_001.jpeg in 1.55 seconds
# Processed 00019591_b438474babc84034becd7d31_step_000.jpeg in 3.08 seconds
# Processed 00017665_9da5be2635544fb284a39a45_step_000.jpeg in 1.98 seconds
# Processed 00017599_410be2bba5a44473ab723de3_step_044.jpeg in 2.39 seconds
# Processed 00011389_766bcadde6e1400e82844498_step_004.jpeg in 1.71 seconds
# Processed 00013072_9084b77631834dd584b2ac93_step_053.jpeg in 2.09 seconds
# Processed: 550/2261
# Processed 00018650_eb344387745a40edb0d7913b_step_028.jpeg in 1.54 seconds
# Processed 00018358_d7049043017e4f0a870a336c_step_000.jpeg in 2.50 seconds
# Processed 00015817_bca56983eee140db9aa4c9a1_step_158.jpeg in 2.13 seconds
# Processed 00017526_462233e03ca64b68bf0ccd1b_step_012.jpeg in 2.06 seconds
# Processed 00015980_c219ae359ef64c4d8e2f4cf2_step_001.jpeg in 1.79 seconds
# Processed 00014017_dd107304e4914da0a8a95060_step_000.jpeg in 1.19 seconds
# Processed 00012871_97d657f2bd0543ccbaad325c_step_021.jpeg in 1.22 seconds
# Processed 00018568_16418acb7e484cd2b68b464c_step_000.jpeg in 0.93 seconds
# Processed 00015755_bca56983eee140db9aa4c9a1_step_096.jpeg in 1.29 seconds
# Processed 00019460_0144af41fb1b47699f11f3ec_step_004.jpeg in 1.94 seconds
# Processed 00015960_09aa78027ec048fd9fe104bb_step_000.jpeg in 2.51 seconds
# Processed 00011415_3d376f30a932449babb6f295_step_008.jpeg in 1.76 seconds
# Processed 00017390_2377343d844e423d880db8c8_step_002.jpeg in 1.72 seconds
# Processed 00010231_2ad3d52d37b347f2a8713bfc_step_002.jpeg in 1.52 seconds
# Processed 00012650_4c0310460f1f43998e607ff3_step_013.jpeg in 1.52 seconds
# Processed 00017714_ed02868cc86f4ab285b5cc5d_step_003.jpeg in 2.21 seconds
# Processed 00010383_78854140e2cb49dd8e9f5835_step_004.jpeg in 2.07 seconds
# Processed 00019900_fa8ec54f3293470ab566c7e0_step_002.jpeg in 1.80 seconds
# Processed 00013925_dbbc429e72ea48c5bb0b1fcd_step_003.jpeg in 1.45 seconds
# Processed 00016949_f3bf486db9ae47c4af145b32_step_000.jpeg in 2.23 seconds
# Processed 00015842_bca56983eee140db9aa4c9a1_step_183.jpeg in 1.21 seconds
# Processed 00016913_937b05ab603f47c49d40bbea_step_000.jpeg in 1.75 seconds
# Processed 00018454_b0a4f6096d0c44a59de285be_step_004.jpeg in 2.36 seconds
# Processed 00014060_38f3e5bc91184985a2d440f6_step_000.jpeg in 1.24 seconds
# Processed 00013434_5d7a1cf7dadc4a2683c8ff82_step_000.jpeg in 2.10 seconds
# Processed 00012735_b17656deace54b61b3130c7e_step_000.jpeg in 1.41 seconds
# Processed 00010560_7d04724c2ebf44dc98695823_step_009.jpeg in 1.85 seconds
# Processed 00016916_1017d3291a464d12be5ec5b4_step_000.jpeg in 1.21 seconds
# Processed 00013653_55a3f8ba1b284e89883e7d58_step_001.jpeg in 0.86 seconds
# Processed 00011169_db6e2de6f4ae4ec493ebe2aa_step_045.jpeg in 1.72 seconds
# Processed 00019967_7259f13b84f34cce843db1f8_step_010.jpeg in 3.37 seconds
# Processed 00013071_9084b77631834dd584b2ac93_step_052.jpeg in 2.13 seconds
# Processed 00017756_5370326b3d7b40f48d9b3be1_step_024.jpeg in 1.70 seconds
# Processed 00017359_49c8ed0f7b9f40ee9db6f574_step_002.jpeg in 2.44 seconds
# Processed 00010021_efca9b37fd1a42a3bd36e852_step_000.jpeg in 2.20 seconds
# Processed 00011630_c4d731b0b8484b3783981916_step_003.jpeg in 2.29 seconds
# Processed 00016915_937b05ab603f47c49d40bbea_step_002.jpeg in 1.93 seconds
# Processed 00013038_9084b77631834dd584b2ac93_step_019.jpeg in 2.85 seconds
# Processed 00016875_a86a8047d2034cafb0c01846_step_000.jpeg in 1.88 seconds
# Processed 00013959_f1648778a3e4453881559657_step_008.jpeg in 1.48 seconds
# Processed 00015060_edd3d06aec774bca9cb146f5_step_004.jpeg in 2.52 seconds
# Processed 00011054_58ce41a52e934d2c8f22384c_step_002.jpeg in 1.75 seconds
# Processed 00011694_1ca1ad2a09504ff1bf83cf74_step_027.jpeg in 1.82 seconds
# Processed 00016073_342309dad0e742b38dd096df_step_000.jpeg in 10.79 seconds
# Processed 00011919_73c6505f827541168d5410e4_step_188.jpeg in 4.27 seconds
# Processed 00014728_957177e368f14306ae253272_step_004.jpeg in 2.96 seconds
# Processed 00014529_41035cff7f614790ae0fb9c0_step_005.jpeg in 1.70 seconds
# Processed 00018346_9fca02afba664b4a938ba05d_step_000.jpeg in 1.09 seconds
# Processed 00017459_28a7687e4fae472399c06676_step_002.jpeg in 2.21 seconds
# Processed 00017648_739d89f4573d40ba9ebe4bb4_step_000.jpeg in 2.00 seconds
# Processed: 600/2261
# Processed 00013101_8a05ec40b85e4b039898097c_step_002.jpeg in 1.46 seconds
# Processed 00015348_373df8dd898a4b0f961a05bd_step_000.jpeg in 1.57 seconds
# Processed 00013362_878b790870f64e228c88a6c6_step_006.jpeg in 1.54 seconds
# Processed 00011252_555cc08bfca944b9a8f5587f_step_000.jpeg in 1.65 seconds
# Processed 00014851_1d8dd0a5ddec465fad59927b_step_001.jpeg in 1.88 seconds
# Processed 00012182_16844b3b4e1441f6aa0343b7_step_000.jpeg in 1.92 seconds
# Processed 00017960_df3d85c7dc3e46b0b4e509a4_step_021.jpeg in 2.24 seconds
# Processed 00015796_bca56983eee140db9aa4c9a1_step_137.jpeg in 1.45 seconds
# Processed 00010111_a35af5bb7a7a42fe9539f3b7_step_003.jpeg in 1.65 seconds
# Processed 00010707_98644e6e040243568b190fb8_step_009.jpeg in 1.96 seconds
# Processed 00012301_b68acac41f4544649f98778c_step_003.jpeg in 1.93 seconds
# Processed 00017099_e04ace2507a948208b6ceef9_step_001.jpeg in 1.45 seconds
# Processed 00010404_3f8b98f0e6b84352819ef9b2_step_007.jpeg in 36.29 seconds
# Processed 00017816_5074ccffa0b549c4a55fb40d_step_000.jpeg in 1.71 seconds
# Processed 00016158_8dadc1c5885e427292f34e71_step_040.jpeg in 2.26 seconds
# Processed 00013328_1ca7296c02f04a7dbc7af5f9_step_006.jpeg in 1.55 seconds
# Processed 00019814_cd8b3c68980a4902848adef4_step_002.jpeg in 1.78 seconds
# Processed 00013419_a7542b094870410b9e34e5a0_step_001.jpeg in 1.38 seconds
# Processed 00018252_f9eb407e63874c939c2157e5_step_007.jpeg in 5.14 seconds
# Processed 00017342_1ceb5eacb8e34050877da3c4_step_001.jpeg in 0.78 seconds
# Processed 00019337_5672a89c7a644e3882c6c85b_step_000.jpeg in 1.09 seconds
# Processed 00015926_1fd2fdd72119499c85058acb_step_000.jpeg in 1.15 seconds
# Processed 00015295_af12ecf5efa94e11b231418b_step_000.jpeg in 1.18 seconds
# Processed 00017497_aac5f5c7554d4648a731cc90_step_005.jpeg in 1.67 seconds
# Processed 00018311_4ac1c1f810da47d8b2164a50_step_000.jpeg in 1.18 seconds
# Processed 00018444_c4b41fffa87e4a7fb2ffd226_step_008.jpeg in 2.33 seconds
# Processed 00017793_4246c2acba2e49bc8da5a93d_step_000.jpeg in 1.96 seconds
# Processed 00013933_dbbc429e72ea48c5bb0b1fcd_step_011.jpeg in 1.84 seconds
# Processed 00017411_2f15831977d247249caf40fe_step_002.jpeg in 2.53 seconds
# Processed 00011637_8f0deb494b1845cb8eaf4caa_step_006.jpeg in 2.79 seconds
# Processed 00016580_3d6966cd42eb44ab8f4224f2_step_120.jpeg in 1.90 seconds
# Processed 00017836_08893609d30e453493c4c079_step_011.jpeg in 1.89 seconds
# Processed 00018059_888c1969193049d68256c128_step_008.jpeg in 2.25 seconds
# Processed 00015534_dd9ee3b0e9804f3f98cdcd20_step_011.jpeg in 4.67 seconds
# Processed 00018620_90abfcfe8e324057a30fa9b5_step_000.jpeg in 2.03 seconds
# Processed 00014889_95bc9987b7e9424e94e86e20_step_000.jpeg in 1.84 seconds
# Processed 00015987_fc8f700e43a54300b95f4f35_step_000.jpeg in 1.51 seconds
# Processed 00014947_546d46eda4ab4b6eaafa2de4_step_034.jpeg in 2.98 seconds
# Processed 00012642_4c0310460f1f43998e607ff3_step_005.jpeg in 2.72 seconds
# Processed 00017127_9534271e3c654e96a9b0f065_step_000.jpeg in 1.73 seconds
# Processed 00013066_9084b77631834dd584b2ac93_step_047.jpeg in 39.13 seconds
# Processed 00013322_1ca7296c02f04a7dbc7af5f9_step_000.jpeg in 4.69 seconds
# Processed 00014528_41035cff7f614790ae0fb9c0_step_004.jpeg in 1.96 seconds
# Processed 00017561_410be2bba5a44473ab723de3_step_006.jpeg in 1.88 seconds
# Processed 00017834_08893609d30e453493c4c079_step_009.jpeg in 1.88 seconds
# ...
# Processed 00018511_26ba3994974941c3ab132a69_step_004.jpeg in 1.96 seconds
# Processed 00010996_8a21002f126e4425a811e70a_step_000.jpeg in 2.14 seconds
# Processed 00016110_bf278319694d434a9536395e_step_000.jpeg in 1.89 seconds
# Processed: 2050/2261
# Processed 00017831_08893609d30e453493c4c079_step_006.jpeg in 2.59 seconds
# Processed 00017641_28ef8351018b4be18377fa7b_step_013.jpeg in 2.25 seconds
# Processed 00018852_b31f7da08a454e6694273e4a_step_072.jpeg in 3.40 seconds
# Processed 00014782_8dabd7d75fe14ac9b78a7d97_step_002.jpeg in 2.47 seconds
# Processed 00015439_d58b545b0ff0468b800f2098_step_000.jpeg in 2.88 seconds
# Processed 00011819_73c6505f827541168d5410e4_step_088.jpeg in 1.46 seconds
# Processed 00011690_1ca1ad2a09504ff1bf83cf74_step_023.jpeg in 1.54 seconds
# Processed 00017371_b5d7b69e6f0745ebb07fcbbe_step_002.jpeg in 1.87 seconds
# Processed 00011699_1ca1ad2a09504ff1bf83cf74_step_032.jpeg in 1.53 seconds
# Processed 00011729_1ca1ad2a09504ff1bf83cf74_step_062.jpeg in 2.27 seconds
# Processed 00011773_73c6505f827541168d5410e4_step_042.jpeg in 2.76 seconds
# Processed 00014525_41035cff7f614790ae0fb9c0_step_001.jpeg in 2.07 seconds
# Processed 00016813_7c761b96a152425886ba3635_step_000.jpeg in 2.10 seconds
# Processed 00014829_47faa9123c0f49b69fee4980_step_028.jpeg in 2.42 seconds
# Processed 00012580_56c9ad6965784b9984fab748_step_005.jpeg in 1.62 seconds
# Processed 00015043_453274d51a7e4f2bb4107b69_step_001.jpeg in 1.63 seconds
# Processed 00016810_d84732cbcd274c709c628f32_step_020.jpeg in 1.76 seconds
# Processed 00015803_bca56983eee140db9aa4c9a1_step_144.jpeg in 2.25 seconds
# Processed 00012061_370f527733f24f86b29d0c4a_step_008.jpeg in 1.69 seconds
# Processed 00015409_f8375a2deaca4dd280611f1a_step_000.jpeg in 1.84 seconds
# Processed 00010708_98644e6e040243568b190fb8_step_010.jpeg in 1.78 seconds
# Processed 00017726_3165e6e713dd43f19cde6f77_step_000.jpeg in 2.23 seconds
# Processed 00014205_cc3b2749a210486987edbe3d_step_002.jpeg in 2.04 seconds
# Processed 00015049_4d3a3befc86f475c86e135ad_step_003.jpeg in 1.76 seconds
# Processed 00015438_3fcf9fa3a8c44c82bba5ef9f_step_006.jpeg in 1.50 seconds
# Processed 00017855_08893609d30e453493c4c079_step_030.jpeg in 1.50 seconds
# Processed 00017230_f53e951dd9d346978cbf4cca_step_000.jpeg in 1.51 seconds
# Processed 00017222_28c2c92fc5914f9d9f98c698_step_000.jpeg in 2.04 seconds
# Processed 00010174_30f2ce809de74ac596f8a219_step_000.jpeg in 1.98 seconds
# Processed 00010153_556de37e0a7447fcbfbdfd22_step_000.jpeg in 2.49 seconds
# Processed 00011048_9ae7b93932c448e9aaeb4849_step_002.jpeg in 1.83 seconds
# Processed 00014751_dcaf8419bbf240f2accc948f_step_002.jpeg in 1.54 seconds
# Processed 00016191_195c8e28989a4913925e894c_step_004.jpeg in 1.94 seconds
# Processed 00013459_bc498028ebbf4328a0dcc953_step_004.jpeg in 2.42 seconds
# Processed 00013414_d9501fc719ec49c68946ad31_step_000.jpeg in 1.46 seconds
# Processed 00017365_63873635940048d1b7983bfd_step_002.jpeg in 1.57 seconds
# Processed 00013765_3104eb9655e34b70beaf18f9_step_002.jpeg in 1.51 seconds
# Processed 00014373_4898b9df95db421ca3eeae4d_step_002.jpeg in 1.85 seconds
# Processed 00013651_f9c6f62ce60a4cbea05f3e63_step_005.jpeg in 1.73 seconds
# Processed 00011175_db6e2de6f4ae4ec493ebe2aa_step_051.jpeg in 1.61 seconds
# Processed 00015946_4fee03e6762d4fefaa49c3d5_step_012.jpeg in 2.07 seconds
# Processed 00010393_dbcff7aa82e44a7fa2e2f462_step_000.jpeg in 1.25 seconds
# Processed 00016018_1cae561158574097b8a3e762_step_000.jpeg in 1.11 seconds
# Processed 00010390_893e5d97c0894460849a6170_step_000.jpeg in 1.37 seconds
# Processed 00013425_c41c20220d2d49909037380f_step_000.jpeg in 2.39 seconds
# Processed 00011572_26a622427a024bf3af381ee6_step_023.jpeg in 2.49 seconds
# Processed 00019406_03713b7964e348598c542318_step_006.jpeg in 2.36 seconds
# Processed 00015785_bca56983eee140db9aa4c9a1_step_126.jpeg in 1.81 seconds
# Processed 00010339_cdece8c89f7b4c6fbb48d2d2_step_002.jpeg in 4.59 seconds
# Processed 00013160_87eaa5ec001a449ab3f5f776_step_001.jpeg in 1.70 seconds
# Processed: 2100/2261
# Processed 00016229_109c897d2b8d49d5a7af94d5_step_004.jpeg in 1.91 seconds
# Processed 00018308_1d4b54eecdee45de98f7a676_step_000.jpeg in 1.55 seconds
# Processed 00016783_3e7761d6f3764d07ba24394e_step_000.jpeg in 2.28 seconds
# Processed 00017335_7b4b171969484b22bd187d54_step_000.jpeg in 1.97 seconds
# Processed 00010400_3f8b98f0e6b84352819ef9b2_step_003.jpeg in 1.68 seconds
# Processed 00011727_1ca1ad2a09504ff1bf83cf74_step_060.jpeg in 1.80 seconds
# Processed 00012800_be38bd57d9c94b8ebe63c5a3_step_000.jpeg in 1.89 seconds
# Processed 00019907_f97c002abbfe448d8111d962_step_002.jpeg in 2.90 seconds
# Processed 00018728_2833c21f6e88409cb1cb3af5_step_000.jpeg in 1.99 seconds
# Processed 00016105_101f5199ed574ecaac1699b5_step_002.jpeg in 2.10 seconds
# Processed 00019482_c3009b533e43403489163a78_step_000.jpeg in 1.80 seconds
# Processed 00011053_58ce41a52e934d2c8f22384c_step_001.jpeg in 1.66 seconds
# Processed 00013648_f9c6f62ce60a4cbea05f3e63_step_002.jpeg in 2.75 seconds
# Processed 00017247_89305d2017d34bd5aa1ecd00_step_000.jpeg in 1.74 seconds
# Processed 00010399_3f8b98f0e6b84352819ef9b2_step_002.jpeg in 1.51 seconds
# Processed 00018306_0adcda98968b4f47b652e48b_step_000.jpeg in 1.92 seconds
# Processed 00014177_9b15e0ea3daa4158a923b32f_step_014.jpeg in 1.75 seconds
# Processed 00019697_f5ac8d924e88451ba0106250_step_001.jpeg in 1.79 seconds
# Processed 00012717_f6e4045a9ded4044becddfb4_step_000.jpeg in 1.38 seconds
# Processed 00010557_7d04724c2ebf44dc98695823_step_006.jpeg in 1.87 seconds
# Processed 00017060_c0b86cb843784f7db8dfeb08_step_001.jpeg in 2.80 seconds
# Processed 00014877_1d2e3d22c38a435287da8196_step_005.jpeg in 1.15 seconds
# Processed 00019454_03713b7964e348598c542318_step_054.jpeg in 1.96 seconds
# Processed 00015814_bca56983eee140db9aa4c9a1_step_155.jpeg in 1.30 seconds
# Processed 00010237_1b6914b4eb444fc6ac3df76a_step_005.jpeg in 1.73 seconds
# Processed 00012817_fe9625aa6ced41b4a8a08d93_step_006.jpeg in 1.54 seconds
# Processed 00019714_80e0b5b4bb5d4bbab04a8621_step_006.jpeg in 3.40 seconds
# Processed 00011174_db6e2de6f4ae4ec493ebe2aa_step_050.jpeg in 1.27 seconds
# Processed 00019826_4dd00f47a609437dbe153afe_step_000.jpeg in 2.01 seconds
# Processed 00016219_c49f4db5fbb64775b170ccc0_step_001.jpeg in 2.39 seconds
# Processed 00017872_eb22dee1de37478b9f2833fa_step_000.jpeg in 1.32 seconds
# Processed 00019846_5f83caa1a2684d018632f66d_step_001.jpeg in 1.30 seconds
# Processed 00014570_a48c6e23df4b4a968d85aa32_step_007.jpeg in 1.84 seconds
# Processed 00013895_e522767f409548409aa29dd2_step_004.jpeg in 2.03 seconds
# Processed 00015191_205e32b6799d428fb44a59aa_step_005.jpeg in 1.54 seconds
# Processed 00016421_a493c115c0124aa3b378693e_step_005.jpeg in 1.73 seconds
# Processed 00017847_08893609d30e453493c4c079_step_022.jpeg in 1.30 seconds
# Processed 00011569_26a622427a024bf3af381ee6_step_020.jpeg in 1.34 seconds
# Processed 00017697_25d833a54aa042a582162192_step_000.jpeg in 1.61 seconds
# Processed 00016107_101f5199ed574ecaac1699b5_step_004.jpeg in 1.43 seconds
# Processed 00012367_79aac98435cf488890eff654_step_001.jpeg in 1.56 seconds
# Processed 00012078_bd0ba1071db44a4cb05e612c_step_013.jpeg in 2.13 seconds
# Processed 00011577_26a622427a024bf3af381ee6_step_028.jpeg in 1.72 seconds
# Processed 00015461_60c3f24c1eb440d1a90693e2_step_000.jpeg in 2.32 seconds
# Processed 00010518_54f5ac0000cf4bcabe0afab7_step_000.jpeg in 2.06 seconds
# Processed 00017707_b5b6a8826185474bb93c0ccd_step_000.jpeg in 1.27 seconds
# Processed 00011437_892c60ebefdc49599d4625b4_step_001.jpeg in 1.50 seconds
# Processed 00012963_d6f21a38d0cf400b9158e9f6_step_002.jpeg in 1.57 seconds
# Processed 00017243_6999428e74144d7aa85857e8_step_004.jpeg in 1.91 seconds
# Processed 00015168_9900bb80c9214dadabcde4f5_step_000.jpeg in 2.05 seconds
# Processed: 2150/2261
# Processed 00017407_c1cd3e9eb80d4f3aa8160974_step_001.jpeg in 1.51 seconds
# Processed 00013082_9084b77631834dd584b2ac93_step_063.jpeg in 2.40 seconds
# Processed 00017349_26460a3f79654a4e9ba9885c_step_002.jpeg in 2.18 seconds
# Processed 00014569_a48c6e23df4b4a968d85aa32_step_006.jpeg in 3.16 seconds
# Processed 00015633_8ebe3c0ee52a4f48ba6d60a5_step_000.jpeg in 8.56 seconds
# Processed 00016687_61ba1971624748939725c43b_step_000.jpeg in 2.72 seconds
# Processed 00013550_f1ecb4be0c4a4f89860c47e6_step_011.jpeg in 1.24 seconds
# Processed 00011956_dc0e2d23884b452e918c5733_step_000.jpeg in 1.99 seconds
# Processed 00013931_dbbc429e72ea48c5bb0b1fcd_step_009.jpeg in 3.61 seconds
# Processed 00016840_7fbf3517801d4081ae119056_step_003.jpeg in 1.88 seconds
# Processed 00018599_423ab08382b847da96d9ff89_step_024.jpeg in 3.96 seconds
# Processed 00017974_df3d85c7dc3e46b0b4e509a4_step_035.jpeg in 1.81 seconds
# Processed 00019139_eea40785089c4b7885a21add_step_000.jpeg in 1.32 seconds
# Processed 00016734_86f63c6c6c7a4bc09bea163c_step_005.jpeg in 2.32 seconds
# Processed 00019450_03713b7964e348598c542318_step_050.jpeg in 1.75 seconds
# Processed 00018646_eb344387745a40edb0d7913b_step_024.jpeg in 2.18 seconds
# Processed 00019798_4bbd66004654476bbcdcaf28_step_001.jpeg in 2.10 seconds
# Processed 00017478_72c836d428f94a42bf9b0c5e_step_002.jpeg in 3.58 seconds
# Processed 00018423_6a88c6c0476244b7bddd0882_step_051.jpeg in 1.83 seconds
# Processed 00012460_cee94f8e0b6c4c18bdf1cecf_step_003.jpeg in 1.89 seconds
# Processed 00018040_3f36fcb1e2ce4e7ba9160573_step_000.jpeg in 2.10 seconds
# Processed 00014374_4898b9df95db421ca3eeae4d_step_003.jpeg in 1.23 seconds
# Processed 00019860_b70051094bda4a84b16d4842_step_001.jpeg in 1.57 seconds
# Processed 00016456_c413749e3efe414c8078a90b_step_000.jpeg in 3.61 seconds
# Processed 00013858_5f60dba564944f9fbb15dc2c_step_001.jpeg in 2.46 seconds
# Processed 00019472_36f0d3351c094ee7bf3e0bd5_step_001.jpeg in 2.42 seconds
# Processed 00019660_a525c0be968848f09cfa76e1_step_000.jpeg in 2.02 seconds
# Processed 00013067_9084b77631834dd584b2ac93_step_048.jpeg in 2.28 seconds
# Processed 00017874_a68eaf6a529a4406ade34548_step_000.jpeg in 8.25 seconds
# Processed 00017962_df3d85c7dc3e46b0b4e509a4_step_023.jpeg in 4.39 seconds
# Processed 00015581_454a67a38de347f98bcab708_step_000.jpeg in 1.71 seconds
# Processed 00019519_666684cba4804c1ab1368b83_step_007.jpeg in 1.74 seconds
# Processed 00012363_305ae0448d2c43599527b98b_step_000.jpeg in 3.37 seconds
# Processed 00016801_d84732cbcd274c709c628f32_step_011.jpeg in 2.29 seconds
# Processed 00017048_0802ebdd812b44879a6a87ba_step_019.jpeg in 1.51 seconds
# Processed 00016209_d3d3764ce81c44e9b3ba9ce2_step_000.jpeg in 1.88 seconds
# Processed 00014480_c7943540d32740df9ad7a90b_step_001.jpeg in 1.68 seconds
# Processed 00011423_fd1f46ad388845919b281092_step_000.jpeg in 1.87 seconds
# Processed 00013471_1ab041344161477f88866872_step_003.jpeg in 2.32 seconds
# Processed 00019817_cccfeb8da3044d6181499d98_step_001.jpeg in 1.56 seconds
# Processed 00016898_da114b2b328b4c5685b27e72_step_003.jpeg in 3.25 seconds
# Processed 00011165_db6e2de6f4ae4ec493ebe2aa_step_041.jpeg in 1.57 seconds
# Processed 00011567_26a622427a024bf3af381ee6_step_018.jpeg in 3.32 seconds
# Processed 00019706_c98e4eec4c7c4c06aa247b38_step_005.jpeg in 1.43 seconds
# Processed 00016271_3e7237e6983a42619182245d_step_003.jpeg in 1.77 seconds
# Processed 00012260_cc084ab0e20e4feea62c2c69_step_000.jpeg in 1.21 seconds
# Processed 00013031_9084b77631834dd584b2ac93_step_012.jpeg in 1.74 seconds
# Processed 00011553_26a622427a024bf3af381ee6_step_004.jpeg in 1.39 seconds
# Processed 00014063_e5926c835688411dabf7adf1_step_000.jpeg in 1.93 seconds
# Processed 00015705_bca56983eee140db9aa4c9a1_step_046.jpeg in 2.18 seconds
# Processed: 2200/2261
# Processed 00018529_84c1a0148fed46a7813f849f_step_000.jpeg in 2.56 seconds
# Processed 00018347_9fca02afba664b4a938ba05d_step_001.jpeg in 1.92 seconds
# Processed 00010394_dbcff7aa82e44a7fa2e2f462_step_001.jpeg in 1.59 seconds
# Processed 00017024_a9e6bd4631714668913bf34f_step_001.jpeg in 1.76 seconds
# Processed 00015037_e83bddb2487a40e5ae3d0f8c_step_000.jpeg in 1.65 seconds
# Processed 00012662_72f41d416d494534840b90ed_step_003.jpeg in 2.42 seconds
# Processed 00017730_ef4898d28c384108bc582464_step_001.jpeg in 1.38 seconds
# Processed 00017381_5129f0683ba6431b8caa6306_step_003.jpeg in 3.44 seconds
# Processed 00019899_fa8ec54f3293470ab566c7e0_step_001.jpeg in 2.15 seconds
# Processed 00017817_5074ccffa0b549c4a55fb40d_step_001.jpeg in 1.32 seconds
# Processed 00017464_7fe719f4aa19469b8a4509af_step_001.jpeg in 1.12 seconds
# Processed 00015826_bca56983eee140db9aa4c9a1_step_167.jpeg in 1.54 seconds
# Processed 00019063_ccb7ba3f97a0483e91f9d971_step_000.jpeg in 4.28 seconds
# Processed 00015891_9f8ba428b2e44d09af19fd02_step_000.jpeg in 1.49 seconds
# Processed 00014167_9b15e0ea3daa4158a923b32f_step_004.jpeg in 2.02 seconds
# Processed 00016457_2b0777e25db9457a94a1b3b1_step_000.jpeg in 2.36 seconds
# Processed 00011038_d4f72cd414fb4fed9b5f88f3_step_006.jpeg in 1.59 seconds
# Processed 00012643_4c0310460f1f43998e607ff3_step_006.jpeg in 1.72 seconds
# Processed 00017037_0802ebdd812b44879a6a87ba_step_008.jpeg in 1.41 seconds
# Processed 00014648_e068e7779e9f4680bc10f981_step_000.jpeg in 2.55 seconds
# Processed 00011025_01b7efc29d2f47508a56383b_step_003.jpeg in 1.88 seconds
# Processed 00012509_26992d92f41141008de4b854_step_005.jpeg in 1.68 seconds
# Processed 00018417_6a88c6c0476244b7bddd0882_step_045.jpeg in 3.55 seconds
# Processed 00010586_cd7450e2c4a3440c932fe366_step_003.jpeg in 1.59 seconds
# Processed 00016941_4662001536db446eb591b5ae_step_000.jpeg in 2.04 seconds
# Processed 00017167_374df395f1434c2393c6a928_step_000.jpeg in 1.47 seconds
# Processed 00018543_056ee70d3bd2402ebc162b9c_step_007.jpeg in 1.87 seconds
# Processed 00012704_0ef9225b93fd4c9db6d7c398_step_000.jpeg in 1.18 seconds
# Processed 00015401_185d605bd2154e13a7d89015_step_002.jpeg in 7.09 seconds
# Processed 00010452_2b3b86cd72de4b749cc012b2_step_002.jpeg in 1.71 seconds
# Processed 00015286_f1a2c1e4ff2541bf91653996_step_002.jpeg in 1.99 seconds
# Processed 00016798_d84732cbcd274c709c628f32_step_008.jpeg in 2.61 seconds
# Processed 00018375_6a88c6c0476244b7bddd0882_step_003.jpeg in 1.90 seconds
# Processed 00017112_62998c1802ae4cfc83be4c9c_step_001.jpeg in 2.97 seconds
# Processed 00015766_bca56983eee140db9aa4c9a1_step_107.jpeg in 2.74 seconds
# Processed 00011566_26a622427a024bf3af381ee6_step_017.jpeg in 1.63 seconds
# Processed 00016817_350498b1081b4452ae53a2f2_step_001.jpeg in 1.73 seconds
# Processed 00019854_62b0b4c462f64f6b80aaea6f_step_002.jpeg in 2.09 seconds
# Processed 00012425_681d83277b174222886cc4b6_step_010.jpeg in 1.76 seconds
# Processed 00015367_78450b1c597248268398f9c8_step_003.jpeg in 1.98 seconds
# Processed 00016809_d84732cbcd274c709c628f32_step_019.jpeg in 2.04 seconds
# Processed 00011296_fb5bb8faab874f0ab7744c7d_step_003.jpeg in 1.95 seconds
# Processed 00013926_dbbc429e72ea48c5bb0b1fcd_step_004.jpeg in 1.69 seconds
# Processed 00018548_0412d6f1457142688e737d8d_step_002.jpeg in 1.47 seconds
# Processed 00010790_297b35a722ab47519729e8f4_step_003.jpeg in 2.18 seconds
# Processed 00017723_2530e0f7fb844685b208c165_step_002.jpeg in 1.73 seconds
# Processed 00014978_276544a891af4e6dabf1a612_step_011.jpeg in 1.55 seconds
# Processed 00016291_ac681e0299b141a9a20e4b4f_step_012.jpeg in 2.11 seconds
# Processed 00015894_b843f44ce1274f0485151055_step_000.jpeg in 2.31 seconds
# Processed 00015484_be73dee7d5754f83a7fddebc_step_006.jpeg in 2.84 seconds
# Processed: 2250/2261
# Processed 00010642_b5f1e56044af446eab0e6238_step_002.jpeg in 1.68 seconds
# Processed 00012455_f54bcfcb352445bf90726b58_step_005.jpeg in 1.59 seconds
# Processed 00012572_50638fbba3b84aa2b6aaddd8_step_000.jpeg in 1.91 seconds
# Processed 00019445_03713b7964e348598c542318_step_045.jpeg in 1.40 seconds
# Processed 00017778_5370326b3d7b40f48d9b3be1_step_046.jpeg in 1.37 seconds
# Processed 00018316_5cd6ab949fbf4b76bc7616ce_step_000.jpeg in 2.41 seconds
# Processed 00013430_97afc606ba8d4cfdae7a4885_step_004.jpeg in 7.80 seconds
# Processed 00016214_5809d02276244eb7ae08a625_step_000.jpeg in 1.93 seconds
# Processed 00018209_a7d5c93728584199a451ee2a_step_000.jpeg in 1.63 seconds
# Processed 00013649_f9c6f62ce60a4cbea05f3e63_step_003.jpeg in 2.61 seconds
# Processed 00015905_976215211d6949998889dcce_step_000.jpeg in 2.31 seconds
# Processed: 2261/2261
# Results saved to cad_captions.csv

# %%
# caption_system_prompt = '''
# Your goal is to generate short, descriptive captions for images of items.
# You will be provided with an item image and the name of that item and you will output a caption that captures the most important information about the item.
# If there are multiple items depicted, refer to the name provided to understand which item you should describe.
# Your generated caption should be short (1 sentence), and include only the most important information about the item.
# The most important information could be: the type of item, the style (if mentioned), the material or color if especially relevant and/or any distinctive features.
# Keep it short and to the point.
# '''
from openai import OpenAI
client = OpenAI()
step_path = "/home/group/cad_codebased/data/abccad/step_under500/abc_0002_step_v00_under500/00020045/00020045_d23cdf27f9ab48f99dcbdaa1_step_002.step"
step_content = extract_data_section(step_path)

image_path = "/home/group/cad_codebased/data/abccad/step_under500_image/abc_0002_step_v00_under500_image/00020045_d23cdf27f9ab48f99dcbdaa1_step_002.jpeg"
base64_image = encode_image(image_path)

text_message = {
    "type": "text",
    "text": f"""
    You are provided with the following DATA section of a CAD model in STEP format:
    {step_content}

    You are also provided with a multi-view image that shows the rendered model. 

    Please do the following:
    1. Determine whether this CAD model depicts an object that can be briefly described in natural language (e.g., "A cylindrical rod with a base").
    2. If it can be described, provide a concise sentence (one or two lines) that accurately captures the object's main geometric or functional characteristics.
    3. If it appears completely random, meaningless, or not describable in simple terms, respond with "cannot be described".

    Return your final answer in the format:
        {{
            "isDescribable": true/false,
            "description": "..."
        }}
    """
}

image_message = {
    "type": "image_url",
    "image_url": {
    "url": f"data:image/jpeg;base64,{base64_image}"
    }
}

def get_caption(text_message, image_message):
    response = client.chat.completions.create(
    model="gpt-4o",
    temperature=0.2,
    max_tokens=300,
    messages=[
        {
            "role": "system",
            "content": "You are a helpful assistant specialized in CAD analysis."
        },
        {
            "role": "user", "content": [text_message, image_message]
        }
    ]
    )

    return response.choices[0].message.content

caption = get_caption(text_message, image_message)
print(f"CAPTION: {caption}\n\n")
# Out:
# CAPTION: ```json
# {
#     "isDescribable": true,
#     "description": "A circular sprocket with a central hub and multiple faces."
# }
# ```
